# %% [markdown]
# # CAPÍTULO 2
# - Datos y Distribuciones de Muestreo
# - Muestreo Aleatorio y Sesgo de Muestra
# - Sesgo
# - Selección Aleatoria
# - Tamaño versus Calidad: ¿Cuándo importa el tamaño?
# - Media de la Muestra versus Media Poblacional
# - Lecturas Adicionales
# - Sesgo de Selección
# - Regresión a la Media
# - Lecturas Adicionales
# - Distribución de Muestreo de una Estadística
# - Teorema del Límite Central
# - Error Estándar
# - Lecturas Adicionales
# - El Bootstrap
# - Remuestreo versus Bootstrap
# - Lecturas Adicionales
# - Intervalos de Confianza
# - Lecturas Adicionales
# - Distribución Normal
# - Normal Estándar y Gráficos QQ
# - Distribuciones de Cola Larga
# - Lecturas Adicionales
# - Distribución t de Student
# - Lecturas Adicionales
# - Distribución Binomial
# - Lecturas Adicionales
# - Distribución Chi-Cuadrado
# - Lecturas Adicionales
# - Distribución F
# - Lecturas Adicionales
# - Distribuciones de Poisson y Relacionadas
# - Distribuciones de Poisson
# - Distribución Exponencial
# - Estimación de la Tasa de Fallos
# - Distribución Weibull
# - Lecturas Adicionales
# - Resumen # CAPÍTULO 2

# %% [markdown]
# # Datos y Distribuciones de Muestreo
#
# Existe una idea equivocada popular que sostiene que la era de los grandes datos significa el fin de la necesidad de realizar muestreos. De hecho, la proliferación de datos de variada calidad y relevancia refuerza la necesidad de los muestreos como una herramienta para trabajar eficientemente con una variedad de datos y minimizar el sesgo. Incluso en un proyecto de grandes datos, los modelos predictivos suelen desarrollarse y probarse con muestras. También se utilizan muestras en pruebas de varios tipos (por ejemplo, comparar el efecto de los diseños de páginas web en los clics).
#
# La Figura 2-1 muestra un esquema que respalda los conceptos que discutiremos en este capítulo: *datos y distribuciones de muestreo*. El lado izquierdo representa una población que, en estadística, se asume que sigue una distribución subyacente pero desconocida. Todo lo disponible es la muestra de datos y su distribución empírica, mostrada en el lado derecho. Para pasar del lado izquierdo al lado derecho, se utiliza un procedimiento de muestreo (representado por una flecha). Las estadísticas tradicionales se enfocaron mucho en el lado izquierdo, utilizando teorías basadas en fuertes suposiciones sobre la población. La estadística moderna se ha trasladado al lado derecho, donde tales suposiciones no son necesarias. En general, los científicos de datos no necesitan preocuparse por la naturaleza teórica del lado izquierdo y, en cambio, deben centrarse en los procedimientos de muestreo y los datos disponibles.
# Hay algunas excepciones notables. A veces, los datos se generan a partir de un proceso físico que puede ser modelado. El ejemplo más simple es lanzar una moneda: esto sigue una distribución binomial. Cualquier situación binomial en la vida real (comprar o no comprar, fraude o no fraude, hacer clic o no hacer clic) puede modelarse eficazmente por una moneda (con una probabilidad modificada de caer cara, por supuesto). En estos casos, podemos obtener una perspectiva adicional utilizando nuestra comprensión de la población.

# %%
# %matplotlib inline

from pathlib import Path
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.utils import resample

import seaborn as sns
import matplotlib.pylab as plt

# %%
try:
    import commin
    DATA = common.dataDirectory()
except ImportError:
    DATA = Path().resolve() / "data"

# %% [markdown]
# Define rutas a conjuntos de datos. Si no guardas tus datos en el mismo directorio que el código, adapta los nombres de las rutas.

# %%
LOANS_INCOME_CSV = DATA / 'loans_income.csv'
SP500_DATA_CSV = DATA / 'sp500_data.csv.gz'

# %%
# Establecer una semilla para la generación de números aleatorios con NumPy para reproducibilidad.
np.random.seed(seed=1)

# Generar valores espaciados uniformemente en el rango -3 a 3 para la variable x.
x = np.linspace(-3, 3, 300)

# Generar una muestra de 1000 valores aleatorios provenientes de una distribución normal.
xsample = stats.norm.rvs(size=1000)

# Crear una figura con dos subgráficos en una fila y tamaño específico.
fig, axes = plt.subplots(ncols=2, figsize=(5, 1.5))

# Configurar el primer subgráfico (izquierda).
ax = axes[0]
ax.fill(x, stats.norm.pdf(x))  # Rellenar el área bajo la curva de la distribución normal estándar.
ax.set_axis_off()  # Desactivar ejes para este subgráfico.
ax.set_xlim(-3, 3)  # Establecer límites en el eje x.

# Configurar el segundo subgráfico (derecha).
ax = axes[1]
ax.hist(xsample, bins=30)  # Crear un histograma de la muestra aleatoria.
ax.set_axis_off()  # Desactivar ejes para este subgráfico.
ax.set_xlim(-3, 3)  # Establecer límites en el eje x.

# Ajustar los márgenes y espacios entre subgráficos en la figura (comentado para que no afecte).
# plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)

# Mostrar la figura.
plt.show()

# %% [markdown]
# ![Captura de pantalla 2024-01-20 002901.png](attachment:d218a0fd-be7e-4553-83e5-c0f504c535d6.png)

# %% [markdown]
# **Figura 2-1**. Población versus muestra

# %% [markdown]
# # Muestreo Aleatorio y Sesgo de Muestra
# Una $Muestra$ *es un subconjunto de datos de un conjunto de datos más grande*; los estadísticos llaman a este conjunto de datos más grande la $Población$. En estadísticas, una población no es lo mismo que en biología; es un conjunto grande, definido (aunque a veces teórico o imaginario) de datos.
#
# El $Muestreo\ aleatorio$ *es un proceso en el cual cada miembro disponible de la población que se está muestreando tiene una probabilidad igual de ser seleccionado para la muestra en cada extracción*. La muestra resultante se llama una $Muestra\ aleatoria\ simple$. El muestreo se puede realizar con reemplazo, en el cual las observaciones se devuelven a la población después de cada extracción para una posible futura reselección. O se puede realizar sin reemplazo, en cuyo caso las observaciones, una vez seleccionadas, no están disponibles para extracciones futuras.
#
# La *calidad de los datos a menudo es más importante que la cantidad de datos al hacer una estimación o un modelo basado en una muestra*. La calidad de los datos en la ciencia de datos implica la completitud, consistencia de formato, limpieza y precisión de los puntos de datos individuales. La estadística agrega la noción de representatividad.

# %% [markdown]
# - $Población$: Todos los estudiantes de una universidad.
# - $Muestra$: 100 estudiantes seleccionados al azar de esa universidad.
#
# $Muestreo Aleatorio$:
# - El $Muestreo\ aleatorio$ es un proceso en el cual cada miembro de la población tiene una probabilidad igual de ser seleccionado para la muestra en cada extracción. Una muestra resultante de este proceso se llama una $Muestra\ aleatoria\ simple$.
#
# - Ejemplo:
#   - Supongamos que queremos realizar un estudio sobre las alturas de los estudiantes de una universidad. Hacemos un muestreo aleatorio seleccionando al azar 50 estudiantes de la población completa. Cada estudiante tiene la misma oportunidad de ser seleccionado.
#
# $Reemplazo\ y\ Sin\ Reemplazo$:
# - El muestreo puede realizarse *con reemplazo*, donde las observaciones se devuelven a la población después de cada extracción, o *sin reemplazo*, donde las observaciones seleccionadas no están disponibles para futuras selecciones.
#
# - Ejemplo:
#   - $Con\ Reemplazo$: Después de seleccionar un estudiante, lo devolvemos a la población antes de seleccionar el siguiente.
#   - $Sin\ Reemplazo$: Después de seleccionar un estudiante, no vuelve a estar disponible para futuras selecciones.
#
# Importancia de la Calidad de los Datos:
# - La calidad de los datos es a menudo más importante que la cantidad al realizar estimaciones o modelos basados en una muestra. Incluye la completitud, consistencia de formato, limpieza y precisión de los datos.
#
# - Ejemplo:
#   - Si estamos modelando los tiempos de respuesta en un sitio web, es crucial que los datos sean precisos y consistentes en su formato para obtener resultados confiables.
#
# Representatividad en Estadísticas:
#   - La estadística agrega la noción de $Representatividad$, es decir, cuán bien la muestra refleja las características de la población.
#
# - Ejemplo:
#   - Si estamos estimando la altura promedio de estudiantes en una universidad, nuestra muestra debe representar adecuadamente la diversidad de alturas en toda la población estudiantil.

# %%
# Leer un archivo CSV llamado "loans_income.csv" desde el directorio 
#"data" y convertirlo en una Serie de pandas.
loans_income = pd.read_csv("data/loans_income.csv").squeeze('columns')

# Crear un DataFrame llamado "sample_data" con 1000 valores aleatorios de la Serie "loans_income" 
# en la columna 'income' y la etiqueta 'Data' en la columna 'type'.
sample_data = pd.DataFrame({
    'income': loans_income.sample(1000),
    'type': 'Data',
})

# Crear un DataFrame llamado "sample_mean_05" con 1000 valores, cada uno siendo la media 
# de 5 valores aleatorios de la Serie "loans_income" y etiquetado como 'Mean of 5'.
sample_mean_05 = pd.DataFrame({
    'income': [loans_income.sample(5).mean() for _ in range(1000)],
    'type': 'Mean of 5',
})

# Crear un DataFrame llamado "sample_mean_20" con 1000 valores, cada uno siendo 
# la media de 20 valores aleatorios de la Serie "loans_income" y etiquetado como 'Mean of 20'.
sample_mean_20 = pd.DataFrame({
    'income': [loans_income.sample(20).mean() for _ in range(1000)],
    'type': 'Mean of 20',
})

# Concatenar los DataFrames "sample_data", "sample_mean_05" y "sample_mean_20" a lo
# largo de las filas y almacenar el resultado en un nuevo DataFrame llamado "results".
results = pd.concat([sample_data, sample_mean_05, sample_mean_20])

# Imprimir las primeras filas del DataFrame "results" para visualizar los datos generados.
print(results.head())
# Out:
#          income  type
# 40292   63000.0  Data
# 38959   92000.0  Data
# 17361  134000.0  Data
# 33996   52000.0  Data
# 26491   43000.0  Data

# %% [markdown]
# ### Términos Clave para Muestreo Aleatorio
#
# ##### Muestra
#
# * Un subconjunto de un conjunto de datos más grande.
#
# ##### Población
#
# * El conjunto de datos más grande o la idea de un conjunto de datos.
#
# ##### $N (n)$
#
# * El tamaño de la población (muestra).
#
# ##### Muestreo aleatorio
#
# * Seleccionar elementos en una muestra al azar.
#
# ##### Muestreo estratificado
#
# * Dividir la población en estratos (conjunto) y seleccionar al azar de cada estrato.
#
# ##### Estrato (pl., estratos)
#
# * Un subgrupo homogéneo de una población con características comunes.
#
# ##### Muestra aleatoria simple
#
# * La muestra que resulta del muestreo aleatorio sin estratificar la población.
#
# ##### Sesgo
#
# * Error sistemático.
#
# ##### Sesgo de muestra
#
# * Una muestra que distorsiona la representación de la población.

# %% [markdown]
# Un ejemplo clásico es la encuesta de Literary Digest de 1936 que predijo una victoria de Alf Landon sobre Franklin Roosevelt. Literary Digest, un destacado periódico de la época, encuestó a toda su base de suscriptores, además de listas adicionales de individuos, un total de más de 10 millones de personas, y predijo una victoria abrumadora para Landon. George Gallup, fundador de la Encuesta Gallup, realizó encuestas quincenales a solo 2,000 personas y predijo con precisión la victoria de Roosevelt. La diferencia radicaba en la selección de las personas encuestadas.
# Literary Digest optó por la cantidad, prestando poca atención al método de selección. Terminaron encuestando a personas con un estatus socioeconómico relativamente alto (sus propios suscriptores, además de aquellos que, por tener lujos como teléfonos y automóviles, aparecían en listas de mercadólogos). El resultado fue un sesgo de muestra; es decir, la muestra era diferente de alguna manera significativa y no aleatoria respecto a la población más grande que se suponía debía representar. El término no aleatorio es importante, ya que casi ninguna muestra, incluidas las muestras aleatorias, será exactamente representativa de la población.
# El sesgo de muestra ocurre cuando la diferencia es significativa y se espera que continúe para otras muestras extraídas de la misma manera que la primera.

# %% [markdown]
# ### Auto-selección de sesgo de muestreo
# Las reseñas de restaurantes, hoteles, cafeterías, y demás que lees en sitios de redes sociales como Yelp son propensas al sesgo porque las personas que las envían no son seleccionadas al azar; más bien, ellas mismas han tomado la iniciativa de escribir. Esto lleva al sesgo de auto-selección: las personas motivadas para escribir reseñas pueden haber tenido experiencias negativas, pueden tener una relación con el establecimiento o simplemente pueden ser un tipo de persona diferente a aquellas que no escriben reseñas. Ten en cuenta que aunque las muestras de auto-selección pueden ser indicadores poco confiables del verdadero estado de las cosas, pueden ser más confiables al simplemente comparar un establecimiento con uno similar; el mismo sesgo de auto-selección podría aplicarse a ambos.

# %% [markdown]
# # Sesgo "BIAS"
# El $Sesgo\ estadístico$ *se refiere a errores de medición o muestreo que son sistemáticos y producidos por el proceso de medición o muestreo*. Debería hacerse una distinción importante entre los errores debidos al azar y los errores debidos al sesgo. Considera el proceso físico de un disparo de un arma hacia un objetivo. No golpeará el centro absoluto del objetivo cada vez, ni siquiera con mucha frecuencia. Un $Proceso\ no\ sesgado$ *producirá error, pero es aleatorio y no tiende fuertemente en ninguna dirección* (ver Figura 2-2). Los resultados mostrados en la Figura 2-3 muestran un proceso sesgado; aún hay error aleatorio tanto en la dirección x como en la y, pero también hay un sesgo. Los disparos tienden a caer en el cuadrante superior derecho.

# %% [markdown]
# ![Captura de pantalla 2024-01-20 003404.png](attachment:9f8401a9-d8b8-4abe-a36e-424f56760e6e.png)

# %% [markdown]
# **Figura 2-2**. Gráfico de dispersión de disparos de un arma con un objetivo verdadero

# %% [markdown]
# ![Captura de pantalla 2024-01-20 003444.png](attachment:efe45df7-95a7-4a26-b15f-3efea26dcc46.png)

# %% [markdown]
# **Figura 2-3**. Gráfico de dispersión de disparos de un arma con un objetivo sesgado

# %% [markdown]
# El sesgo se presenta en diferentes formas y puede ser observable o invisible. Cuando un resultado sugiere sesgo (por ejemplo, mediante referencia a un punto de referencia o valores reales), suele ser un indicador de que un modelo estadístico o de aprendizaje automático ha sido mal especificado, o se ha omitido una variable importante.

# %% [markdown]
# ### Ejemplo: Sesgo estadístico
#
#   - El $Sesgo\ estadístico$ se refiere a errores sistemáticos en la medición o el muestreo que son consistentes y provienen del proceso en sí. Es importante distinguir entre errores aleatorios y sesgo; mientras que los errores aleatorios son impredecibles y se distribuyen al azar, el sesgo sigue un patrón constante.
#
# Supongamos que estás midiendo la altura de una población de estudiantes utilizando un dispositivo de medición que está ligeramente descalibrado. Este sesgo en la medición introducirá un error sistemático en tus resultados.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generar datos de alturas de estudiantes con un sesgo
np.random.seed(42)   # Establecer la semilla para reproducibilidad de resultados
altura_real = 170    # Definir la altura promedio real en centímetros
sesgo_medicion = 2    # Establecer el sesgo en el dispositivo de medición

# Simular la medición de alturas con sesgo
muestras = 1000
# Generar alturas medidas con sesgo
alturas_medidas = np.random.normal(altura_real + sesgo_medicion, 5, muestras)  

# Graficar los resultados
plt.figure(figsize=(8, 6))  # Crear una figura de tamaño 8x6 pulgadas
# Crear un histograma de las alturas medidas
plt.hist(alturas_medidas, bins=30, color="skyblue", edgecolor="black")  
# Línea vertical para la altura real
plt.axvline(x=altura_real, color="red", linestyle="dashed", linewidth=2, label="Altura real")  
# Línea vertical para la media de alturas medidas
plt.axvline(x=np.mean(alturas_medidas), color="green", linestyle="dashed", linewidth=2, label="Media medida")  
plt.xlabel("Altura (cm)")  # Etiqueta del eje x
plt.ylabel("Frecuencia")  # Etiqueta del eje y
plt.title("Medición de Alturas con Sesgo")  # Título del gráfico
plt.legend()  # Mostrar la leyenda
plt.show()  # Mostrar el gráfico

# %% [markdown]
# Es este ejemplo, la altura real promedio de los estudiantes es 170 cm, pero el dispositivo de medición introduce un sesgo de 2 cm. La distribución de alturas medidas mostrará un sesgo sistemático, ya que las mediciones tienden a ser mayores de los que realmente son. La línea roja representa la altura real, mientras que la línea verde representa la media de las alturas medidas, que está sesgada debido al sesgo en el dispositivo de medición.
#
# Este sesgo ilustra cómo los errores sistemáticos pueden afectar las mediciones y la importancia de tener en cuenta el sesgo al intepretar los resultado estadísticos.

# %% [markdown]
# # Selección Aleatoria
# Para evitar el problema de sesgo de muestra que llevó a Literary Digest a predecir la victoria de Landon sobre Roosevelt, George Gallup (mostrado en la Figura 2-4) optó por métodos más científicamente seleccionados para lograr una muestra representativa del electorado estadounidense. Ahora existen diversas formas de lograr representatividad, pero en el centro de todas ellas se encuentra el $Muestreo\ aleatorio$.

# %% [markdown]
# ![Captura de pantalla 2024-01-20 003605.png](attachment:03e28cdf-4eb9-43ad-9c6b-285ebff09bed.png)

# %% [markdown]
# **Figura 2-4**. George Gallup, catapultado a la fama por el "fracaso de datos masivos" de Literary Digest

# %% [markdown]
# El muestreo aleatorio no siempre es fácil. Una definición adecuada de una población accesible es clave. Supongamos que queremos generar un perfil representativo de clientes y necesitamos realizar una encuesta piloto a los clientes. La encuesta debe ser representativa pero es intensiva en mano de obra. Primero, necesitamos definir quién es un cliente. Podríamos seleccionar todos los registros de clientes donde la cantidad de compra $> 0$. ¿Incluimos a todos los clientes anteriores? ¿Incluimos reembolsos? ¿Compras de prueba internas? ¿Revendedores? ¿Tanto al agente de facturación como al cliente?
# Luego, necesitamos especificar un procedimiento de muestreo. Podría ser "seleccionar 100 clientes al azar". Donde esté involucrado un muestreo de un flujo (por ejemplo, transacciones de clientes en tiempo real o visitantes web), las consideraciones de tiempo pueden ser importantes (por ejemplo, un visitante web a las 10 a. m. en un día laborable puede ser diferente de un visitante web a las 10 p. m. en un fin de semana).
# En el $Muestreo\ estratificado$, *la población se divide en estratos y se toman muestras aleatorias de cada estrato*. Los encuestadores políticos podrían buscar conocer las preferencias electorales de blancos, negros e hispanos. Una simple muestra aleatoria tomada de la población daría muy pocos negros e hispanos, por lo que esos estratos podrían ponderarse más en el muestreo estratificado para obtener tamaños de muestra equivalentes.

# %% [markdown]
# ### Ejemplo: Selección aleatoria
#
# Supongamos que queremos simular la selección aleatoria de estudiantes para realizar una encuentra sobre sus hábitos de estudio en una universidad. Utilizaremos la biblioteca `random` para realizar la selección aleatoria.

# %%
import random

# %%
# Lista de estudiantes en la universidad
lista_estudiantes = ["Estudiante1", "Estudiante2", "Estudiante3", "Estudiante4",
                     "Estudiante5", "Estudiante6", "Estudiante7", "Estudiante8",
                     "Estudiante9", "Estudiante10"]

# Número de estudiantes a saleccionar para la encuesta
numero_muestra = 3

# Selección aleatoria de estudiantes para la encuenta
muestra_seleccionada = random.sample(lista_estudiantes, numero_muestra)

# Mostrar los estudiantes seleccionados
print("Estudiantes seleccionados para la encuesta:")
for estudiante in muestra_seleccionada:
    print(estudiante)
# Out:
# Estudiantes seleccionados para la encuesta:
# Estudiante1
# Estudiante4
# Estudiante5

# %% [markdown]
# Este código simula la selección aleatoria de 3 estudiantes de la lista total de estudiantes en la universidad. La función `random.sample()` se utiliza para realizar la selección aleatoria sin reemplazo, asegurando que cada estudiante seleccionado sea único.
# En el contexto de una encuesta, esta selección aleatoria ayuda a garantizar que la muestra sea representativa de la población de estudiantes en la universidad, evitando así sesgos en la resultados de la encuesta.

# %% [markdown]
# # Tamaño versus Calidad: ¿Cuándo importa el tamaño?
# En la era del big data, a veces resulta sorprendente que menos es mejor. El tiempo y el esfuerzo dedicados al muestreo aleatorio no solo reducen el sesgo, sino que también permiten prestar una mayor atención a la exploración de datos y a la calidad de los datos. Por ejemplo, los datos faltantes y los valores atípicos pueden contener información útil. Puede ser prohibitivamente caro rastrear los valores faltantes o evaluar los valores atípicos en millones de registros, pero hacerlo en una muestra de varios miles de registros puede ser factible. La representación gráfica de datos y la inspección manual se ralentizan si hay demasiados datos.
#
# Entonces, ¿cuándo se necesitan cantidades masivas de datos?
# El escenario clásico para el valor de big data es cuando los datos no solo son grandes, sino también dispersos. Consideremos las consultas de búsqueda recibidas por Google, donde las columnas son términos, las filas son consultas de búsqueda individuales y los valores de las celdas son 0 o 1, según si una consulta contiene un término. El objetivo es determinar el mejor destino de búsqueda previsto para una consulta dada. Hay más de 150,000 palabras en el idioma inglés, y Google procesa más de un billón de consultas al año. Esto da como resultado una matriz enorme, cuya inmensa mayoría de las entradas son "0".
#
# Este es un verdadero problema de big data; solo cuando se acumulan cantidades tan enormes de datos se pueden devolver resultados de búsqueda efectivos para la mayoría de las consultas. Y cuanto más se acumula data, mejores son los resultados. Para términos de búsqueda populares, esto no es un problema grave; se puede encontrar datos efectivos bastante rápido para el puñado de temas extremadamente populares que son tendencia en un momento particular. El valor real de la tecnología de búsqueda moderna radica en la capacidad para devolver resultados detallados y útiles para una gran variedad de consultas de búsqueda, incluso aquellas que ocurren con una frecuencia de solo una entre un millón.
#
# Considera la frase de búsqueda "Ricky Ricardo y Caperucita Roja". En los primeros días de Internet, esta consulta probablemente habría devuelto resultados sobre el líder de la banda Ricky Ricardo, el programa de televisión I Love Lucy en el que aparecía ese personaje y la historia infantil de Caperucita Roja. Ambos elementos individuales habrían tenido muchas búsquedas a las que referirse, pero la combinación habría tenido muy pocas. Más tarde, ahora que se han acumulado billones de consultas de búsqueda, esta consulta devuelve el episodio exacto de I Love Lucy en el que Ricky narra, de manera dramática, la historia de Caperucita Roja a su hijo en una mezcla cómica de inglés y español.
#
# Ten en cuenta que el número de registros pertinentes reales, es decir, aquellos en los que aparece esta consulta de búsqueda exacta o algo muy similar (junto con información sobre qué enlace hizo clic la gente finalmente), podría necesitar solo estar en el rango de miles para ser efectivo. Sin embargo, se necesitan muchos billones de puntos de datos para obtener estos registros pertinentes (y el muestreo aleatorio, por supuesto, no ayudará). Véase también "Distribuciones de cola larga" en la página 73.

# %% [markdown]
# # Media de la Muestra versus Media de la Población
#
# El símbolo $\bar{x}$ (pronunciado "$x-bar$") se utiliza para representar la media de una muestra tomada de una población, mientras que $μ$ se utiliza para representar la media de toda una población. ¿Por qué hacer esta distinción? La información sobre las muestras se observa, y la información sobre poblaciones grandes a menudo se infiere a partir de muestras más pequeñas. A los estadísticos les gusta mantener separadas estas dos cosas en la simbología.

# %% [markdown]
# - Media de la Muestra ($\bar{x}$):
#   - Definición:
#     - El símbolo $\bar{x}$ (pronunciado "barra x") se utiliza para representar la media de una muestra tomada de una población.
#   - Ejemplo:
#     - Si tomamos una muestra de 100 estudiantes de una universidad y calculamos la media de sus alturas, esa sería $\bar{x}$.
#
# - Media de la Población ($μ$):
#   - Definición:
#     - El símbolo $μ$ se utiliza para representar la media de toda una población.
#   - Ejemplo:
#     - Si quisiéramos conocer la altura promedio de todos los estudiantes en una universidad (no solo de la muestra de 100), usaríamos $μ$.
#
# Importancia de la Distinción:
# - Razón:
#   - La información sobre las muestras se observa directamente, mientras que la información sobre poblaciones grandes a menudo se infiere a partir de muestras más pequeñas.
# - Ejemplo:
#   - Supongamos que queremos estimar la altura promedio de todos los estudiantes en una universidad. Sería poco práctico medir la altura de todos y cada uno de los estudiantes. En cambio, medimos la altura de una muestra de 100 estudiantes y usamos $\bar{x}$ como una estimación de $μ$.
#
# Ejemplo Práctico:
# - Situación:
#   - Queremos estimar el tiempo promedio que los estudiantes pasan estudiando por semana en una universidad.
# - Procedimiento:
#   - Tomamos una muestra de 50 estudiantes y registramos el tiempo que cada uno pasa estudiando.
# - Resultados:
#   - La media de esta muestra sería $\bar{x}$, representando el tiempo promedio de estudio para estos 50 estudiantes.
#   - Sin embargo, queremos hacer una inferencia sobre la media de estudio para todos los estudiantes de la universidad, que sería $μ$.
#
# Importancia de la Inferencia:
# - Razón:
#   - A menudo, no podemos medir directamente la media de toda una población. Inferimos esta información basándonos en las observaciones de nuestras muestras.
# - Ejemplo:
#   - Si encontramos que $\bar{x}$ (tiempo promedio de estudio en nuestra muestra) es 15 horas por semana, podemos inferir que $μ$ (tiempo promedio de estudio para todos los estudiantes en la universidad) es probablemente cercano a ese valor, pero no necesariamente exactamente 15 horas.

# %% [markdown]
# ### Ejemplo: Diferencia entre la media de una muestra $\bar{x}$ y la media de la población $\mu$
#
# Supongamos que queremos estudiar la altura de los estudiantes de una universidad.

# %%
import numpy as np

# Definir la altura promedio de la población (μ)
altura_promedio_poblacion = 170    # En centímetros

# Generar una muestra de alturas de estudiantes
np.random.seed(123)    # Para reproducibilidad
# Muestra de 20 estudiantes
muestra_alturas = np.random.normal(altura_promedio_poblacion, 5, 20)   

# Calcular la media de la muestra (𝑥̅)
media_muestra = np.mean(muestra_alturas)

# Mostrar los resultados
print(f"Altura promedio de la población (μ): {altura_promedio_poblacion} cm")
print(f"Alturas de la muestra: {muestra_alturas}")
print(f"Media de la muestra (𝑥̅): {media_muestra:.2f} com")
# Out:
# Altura promedio de la población (μ): 170 cm
# Alturas de la muestra: [164.57184698 174.98672723 171.41489249 162.46852643 167.10699874
#  178.25718269 157.86660378 167.85543686 176.32968129 165.66629799
#  166.60556924 169.52645516 177.45694813 166.80549002 167.7800902
#  167.82824362 181.02965041 180.93393044 175.02026949 171.930932  ]
# Media de la muestra (𝑥̅): 170.57 com

# %% [markdown]
# En este ejemplo, hemos definido una altura promedio de la población `altura_promedio_poblacion` y hemos generado una muestra de alturas de estudiantes utilizando una distribución normal. Luego, calculamos la media de la muestra `media_muestra` utilizando la función `np.mean()`.
#
# Es importante destacar que la media de la muestra (𝑥̅) puede variar de una muestra a otra, ya que se basa en datos observados, En contraste, la media de la población (μ) es una constante que representa el valor promedio de toda la población.
#
# Al ejecutar este código, obtendras resultados diferentes cada vez que lo ejecutes devido a que la naturaleza aleatoria de la generación de la muestra. Sin embargo, la media de la población se mantiene constante. Este ejemplo iluestra cómo se utiliza la notación para distinguir entre la infromación derivada de muestras y la información sobre la población completa.

# %%
# Crear un histograma
plt.hist(muestra_alturas, bins=10, color="skyblue", edgecolor="black")
plt.axvline(x=altura_promedio_poblacion, color="red", linestyle="dashed",
            linewidth=2, label="Altura Promedio de la Población")
plt.axvline(x=media_muestra, color="green", linestyle="dashed", linewidth=2,
            label="Media de la Muestra")
plt.xlabel("Altura (cm)")
plt.ylabel("Frecuencia")
plt.title("Distribución de Alturas de la Muestra")
plt.legend()
plt.show()

# %% [markdown]
# Este código generará un histograma de las alturas de la muestra con líneas punteadas que indican la altura promedio de la población y la media de la muestra. Esto te permitirá visualizar cómo se distribuyen las alturas de la muestra en comparación con la altura promedio de la población.

# %% [markdown]
# ### Ideas Clave
# * Incluso en la era de los grandes datos, el muestreo aleatorio sigue siendo una herramienta importante en el arsenal del científico de datos.
# * El sesgo ocurre cuando las mediciones u observaciones tienen sistemáticamente errores porque no son representativas de toda la población.
# * La calidad de los datos a menudo es más importante que la cantidad de datos, y el muestreo aleatorio puede reducir el sesgo y facilitar la mejora de la calidad, lo que de lo contrario sería prohibitivamente costoso.

# %% [markdown]
# ### Lecturas Adicionales
# * Una revisión útil de los procedimientos de muestreo se puede encontrar en el capítulo "Sampling Methods for Online Surveys" en The SAGE Handbook of Online Research Methods, 2da edición, editado por Nigel G. Fielding, Raymond M. Lee y Grant Blank (SAGE Publications, 2016). Este capítulo incluye una revisión de las modificaciones al muestreo aleatorio que a menudo se utilizan por razones prácticas de costo o viabilidad.
# * La historia del fracaso de la encuesta de Literary Digest se puede encontrar en el sitio web Capital Century.

# %% [markdown]
# # Sesgo de selección "Selection Bias"
# Parafraseando a Yogi Berra: si no sabes lo que estás buscando, busca lo suficientemente duro y lo encontrarás.
# El $Sesgo\ de\ selección$ *se refiere a la práctica de elegir selectivamente datos, de manera consciente o inconsciente, de una manera que lleva a una conclusión que es engañosa o efímera*.
# Si especificas una hipótesis y realizas un experimento bien diseñado para probarla, puedes tener alta confianza en la conclusión. Sin embargo, esto frecuentemente no es lo que ocurre. A menudo, se examinan los datos disponibles y se intenta discernir patrones. Pero, ¿son los patrones reales? ¿O son simplemente el producto de buscar extensivamente en los datos hasta que algo interesante surge? Hay un dicho entre los estadísticos: "*Si torturas los datos lo suficiente, tarde o temprano confesarán*".
#
# La diferencia entre un fenómeno que verificas al probar una hipótesis mediante un experimento y un fenómeno que descubres al revisar los datos disponibles se puede ilustrar con el siguiente experimento mental.
#
# Imagina que alguien te dice que puede lanzar una moneda y hacer que salga cara en los próximos 10 lanzamientos. Lo desafías (equivalente a un experimento), y proceden a lanzar la moneda 10 veces, con todos los lanzamientos saliendo cara. Claramente, le atribuyes algún talento especial: la probabilidad de que 10 lanzamientos de moneda salgan cara solo por casualidad es de 1 entre 1,000.
#
# Ahora imagina que el anunciador en un estadio deportivo le pide a las 20,000 personas presentes que lancen una moneda 10 veces y que informen a un acomodador si obtienen 10 caras seguidas. La probabilidad de que alguien en el estadio obtenga 10 caras es extremadamente alta (más del 99%, es decir, 1 menos la probabilidad de que nadie obtenga 10 caras). Claramente, seleccionar después del hecho a la persona (o personas) que obtiene 10 caras en el estadio no indica que tengan algún talento especial, es más probable que sea suerte.
#
# Dado que la revisión repetida de grandes conjuntos de datos es una propuesta de valor clave en la ciencia de datos, el sesgo de selección es algo de lo que preocuparse. Una forma de sesgo de selección de particular preocupación para los científicos de datos es lo que John Elder (fundador de Elder Research, una respetada consultora de minería de datos) llama el $Efecto\ de\ búsqueda\ vasta$. Si ejecutas repetidamente diferentes modelos y haces diferentes preguntas con un gran conjunto de datos, seguramente encontrarás algo interesante. Pero, ¿es el resultado que encontraste realmente algo interesante o es solo un valor atípico por casualidad?
#
# Podemos protegernos contra esto utilizando un conjunto de retención y, a veces, más de un conjunto de retención, con el que validar el rendimiento. Elder también aboga por el uso de lo que él llama "target shuffling" (una prueba de permutación, en esencia) para probar la validez de las asociaciones predictivas que sugiere un modelo de minería de datos.
#
# Formas típicas de sesgo de selección en estadísticas, además del efecto de búsqueda vasta, incluyen el $Muestreo\ no\ aleatorio$, la selección selectiva de datos, la selección de intervalos de tiempo que acentúan un efecto estadístico particular y detener un experimento cuando los resultados parecen "interesantes".

# %% [markdown]
# ### Ejemplo: Sesgo de selección

# %% [markdown]
# Consideremos un escenario en el ámbito de la salud. Supongamos que un grupo de investigadores está llevando a cabo un estudio sobre la efectividad de una nueva dieta para perder peso. Después de recopilar datos de varios participantes, deciden analizar solo los casos en los que los participantes han perdido peso significativamente.

# %%
import numpy as np

# Generar datos ficticios de pérdida de peso
np.random.seed(123)
peso_inicial = np.random.normal(70, 5, 100)  # Peso inicial en kilogramos
perdida_peso = np.random.normal(3, 2, 100)  # Pérdida de peso en kilogramos

# Crear un DataFrame de Pandas para almacenar los datos
import pandas as pd
datos = pd.DataFrame({'Peso Inicial': peso_inicial, 'Pérdida de Peso': perdida_peso})

# Seleccionar solo los casos de pérdida de peso significativa (sesgo de selección)
casos_seleccionados = datos[datos['Pérdida de Peso'] > 4]

# Mostrar los resultados
print("Datos originales:")
print(datos.head())
print("\nCasos seleccionados con pérdida de peso significativa:")
print(casos_seleccionados.head())
# Out:
# Datos originales:
#    Peso Inicial  Pérdida de Peso
# 0     64.571847         4.284109
# 1     74.986727        -0.955776
# 2     71.414892         4.424529
# 3     62.468526         8.196608
# 4     67.106999         2.950748
#
# Casos seleccionados con pérdida de peso significativa:
#     Peso Inicial  Pérdida de Peso
# 0      64.571847         4.284109
# 2      71.414892         4.424529
# 3      62.468526         8.196608
# 11     69.526455         5.485739
# 13     66.805490         4.002498

# %% [markdown]
# En este ejemplo, los investigadores deciden analizar solo aquellos casos donde la pérdida de peso es significativa (meyor a 4 kilogramos). Al hacerlo, podrían concluir que la nueva dieta es altamente efectiva para la pérdida de peso. Sin embargo, este enfoque introduce un sesgo de selección, ya que solo se están considerando los casos que muestran un resultado especifico.
#
# Este sesgo de selección podría llevar a conclusiones engañosas sobre la efectividad general de la dieta, ya que no se están teniendo en cuenta aquellos casos donde la pérdida de peso no fue significativa. Es importante reconocer y abordar el sesgo de selección para obtener conclusiones más precisas y representativas en la investigación científica y el análisis de datos.

# %%
# Crea un gráfico de dispersión con tamaño de figura de 10x6 pulgadas
plt.figure(figsize=(5, 5))
# Dibuja un gráfico de dispersión con los datos originales
plt.scatter(datos["Peso Inicial"], datos["Pérdida de Peso"],
            label="Datos Originales", alpha=0.5)
# Dibuja un segundo conjunto de puntos resaltando los casos seleccionados en rojo
plt.scatter(casos_seleccionados["Peso Inicial"], casos_seleccionados["Pérdida de Peso"],
            color="red", label="Casos Seleccionados")
# Etiqueta el eje x con "Peso Inicial (kg)"
plt.xlabel("Peso Inicial (kg)")
# Etiqueta el eje y con "Pérdida de Peso (kg)"
plt.ylabel("Pérdida de Peso (kg)")
# Asigna un título al gráfico
plt.title("Gráfico de Dispersión de Peso Inicial vs. Pérdida de Peso")
# Muestra la leyenda en el gráfico
plt.legend()
# Habilita la cuadrícula en el gráfico
plt.grid(True)
# Muestra el gráfico
plt.show()

# %% [markdown]
# Este código generará un gráfico de dispersión con los datos originales y resaltará en rojo los casos seleccionados con pérdida de peso significativa. El eje x representa el peso inicial, el eje y representa la pérdida de peso y cada punto en el gráfico corresponde a un individuo en tu muestra.

# %% [markdown]
# - El sesgo de selección se refiere a la práctica de elegir selectivamente datos, de manera consciente o inconsciente, de una manera que lleva a una conclusión engañosa o efímera.
#
# Ilustración con un Ejemplo:
#
# Imagina que estás analizando los resultados de un nuevo tratamiento médico para una enfermedad y te encuentras con un patrón inusual en los datos.
#
# - Escenario de Sesgo de Selección:
#   - Descripción:
#     - Después de revisar los datos, encuentras que aquellos pacientes que siguieron el tratamiento durante más tiempo mostraron mejoras significativas en comparación con los que lo abandonaron temprano.
#   - Problema de Sesgo:
#     - La conclusión podría estar sesgada, ya que aquellos que abandonaron el tratamiento temprano podrían haberlo hecho debido a la falta de mejoras, lo que introduce un sesgo de selección. Puedes estar viendo solo los casos en los que el tratamiento parece funcionar, ignorando a aquellos que no respondieron y abandonaron el tratamiento.
#
# Experimento Mental para Entender el Sesgo de Selección:
#
# - Escenario del Estadio:
#   - Situación:
#     - Imagina que estás en un estadio deportivo con 20,000 personas.
#   - Experimento Mental:
#     - Se les pide a todas las personas en el estadio que lancen una moneda 10 veces y notifiquen si obtienen 10 caras seguidas.
#   - Resultado:
#     - Aunque es probable que varias personas en el estadio obtengan 10 caras seguidas por pura casualidad, seleccionar después del hecho a aquellas personas que tuvieron éxito no indica necesariamente algún talento especial, es más probable que sea suerte.
#
# Importancia del Sesgo de Selección en Ciencia de Datos:
#
# - Razón:
#   - Dado que la revisión repetida de grandes conjuntos de datos es una propuesta de valor clave en la ciencia de datos, el sesgo de selección es algo de lo que preocuparse.
#   - Ejecutar repetidamente diferentes modelos o hacer diferentes preguntas con un gran conjunto de datos puede llevar a encontrar algo interesante solo por casualidad.
#
# Prevención del Sesgo de Selección:
#
# - Sugerencias:
#   - Utilizar conjuntos de retención para validar el rendimiento.
#   - Aplicar pruebas de permutación o "target shuffling" para validar asociaciones predictivas sugeridas por modelos de minería de datos.
#
# Formas Típicas de Sesgo de Selección en Estadísticas:
#
# - Efecto de Búsqueda Vasta:
#   - Ejecutar repetidamente análisis hasta encontrar algo interesante.
#
# - Muestreo No Aleatorio:
#   - Seleccionar muestras de manera no aleatoria, distorsionando la representatividad.
#
# - Selección Selectiva de Datos:
#   - Elegir consciente o inconscientemente datos que respalden una conclusión preexistente.
#
# - Selección de Intervalos de Tiempo:
#   - Seleccionar intervalos de tiempo específicos que resalten un efecto estadístico particular.
#
# - Detener un Experimento Prematuramente:
#   - Detener un experimento cuando los resultados parecen "interesantes", ignorando la posibilidad de resultados aleatorios.
#
# En resumen, el sesgo de selección es crucial para comprender la validez de las conclusiones en ciencia de datos y estadísticas, y su prevención implica prácticas cuidadosas de validación y pruebas.

# %% [markdown]
# ### Términos clave para Sesgo de selección
#
# ##### Sesgo de selección
#
# * Sesgo resultante de la forma en que se seleccionan las observaciones.
#
# ##### Data snooping
#
# * Investigación extensiva a través de datos en busca de algo interesante.
#
# ##### Efecto de búsqueda vasta
#
# * Sesgo o falta de reproducibilidad resultante de la modelización repetida de datos o la modelización de datos con un gran número de variables predictoras.

# %% [markdown]
# # Regresión a la Media
#
# La "Regresión a la Media" se refiere a un fenómeno que involucra mediciones sucesivas en una variable dada: las observaciones extremas tienden a ser seguidas por otras más centrales. Poner un enfoque y significado especial en el valor extremo puede llevar a una forma de sesgo de selección.
#
# Los aficionados a los deportes están familiarizados con el fenómeno del "Novato del Año, declive en segundo año". Entre los atletas que comienzan su carrera en una temporada determinada (la clase de novatos), siempre hay uno que tiene un rendimiento mejor que todos los demás. Generalmente, este "Novato del Año" no tiene un rendimiento tan bueno en su segundo año. ¿Por qué?
#
# En casi todos los deportes principales, al menos los que se juegan con una pelota o puck, hay dos elementos que influyen en el rendimiento general:
# - Habilidad
# - Suerte
#
# La regresión a la media es una consecuencia de una forma particular de sesgo de selección. Cuando seleccionamos al novato con el mejor rendimiento, la habilidad y la buena suerte probablemente estén contribuyendo. En su próxima temporada, la habilidad seguirá presente, pero muy a menudo la suerte no estará, por lo que su rendimiento disminuirá; experimentará una regresión. Este fenómeno fue identificado por primera vez por Francis Galton en 1886 [Galton-1886], quien escribió al respecto en relación con las tendencias genéticas; por ejemplo, los hijos de hombres extremadamente altos tienden a no ser tan altos como su padre (ver Figura 2-5).
#
# La $Regresión\ de\ la\ media$ es un fenómeno estadístico que se refiere a la tendencia de las observaciones extremas al acercarse al promedio en mediciones repetidas. En otras palabras, cuando se observan valores extremadamente altos o bajos en una medición inicial, es probable que en mediciones posteriores esos valores extremos se regresen hacia el promedio.
#
# Este fenómeno se puede entender con un ejemplo. Supongamos que estás mediendo al altura de padres e hijos en una población. Si un padre es excepcionalmente alto, es probable que su hijo herede parte de esa altura, pero no necesariamente toda. En la primera generación, es posible que el hijo sea más alto que el promedio debido a la influencia genética del padre. Sin embargo, es probable que el hijo no sea tan extremadamente alto como el padre en la siguiente generación.
#
# La regresión a la media puede explicarse en términos de variabilidad y heredabilidad. Si hay variabilidad en caracteristicas y esas caracteristicas es en parte heredable, las observaciones extremas tienen a regresar hacia el promedio en la generaciones siguientes debido a la influencia combinada de la genética y otros factores.
#
# En el contexto de ciencia de datos, la regresión a la media es importante tenerla en cuenta al interpretar resultado y predicciones. Cuando observas valores extremos en un conjunto de datos, es posible que en mediciones futuras esos valores extremos se acerquen al promedio debido a este fenómeno. Por lo tanto es crucial entender y considerar la regresión a la media al realizar análisis y modelado estadístico.

# %% [markdown]
# ### Ejemplo: Regresión a la media
#
# Imaginemos que estamos analizando el rendimiento académico de los estudiantes de una escuela secundaria. Vamos a considerar dos mediciones sucesivas de las calificaciones en matemáticas de un grupo de estudiantes.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos ficticios de calificaciones en matemáticas
np.random.seed(123)
calificaciones_primer_semestre = np.random.normal(80, 10, 50)  # Calificaciones en el primer semestre
calificaciones_segundo_semestre = 0.7 * calificaciones_primer_semestre + np.random.normal(0, 5, 50)  # Regresión a la media

# Crear un gráfico para visualizar las calificaciones
plt.figure(figsize=(5, 5))

plt.scatter(calificaciones_primer_semestre, calificaciones_segundo_semestre, color='blue', label='Estudiantes')
plt.plot([0, 100], [0, 100], '--', color='red', label='Línea de Regresión a la Media')
plt.title('Regresión a la Media en Calificaciones de Matemáticas')
plt.xlabel('Calificaciones Primer Semestre')
plt.ylabel('Calificaciones Segundo Semestre')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# En este ejemplo, hemos generado calificaciones en matemáticas para el primer semestre y luego creado una relación para el segundo semestre que incluye una regresión a la media. La relación entre las calificaciones del primer y segundo semestre está influenciada por la regresión a la media, lo que significa que las calificaciones extremas en el primer semestre tienden a acercarse al promedio en el segundo semestre.
#
# El gráfico muestra puntos que representan a los estudiantes en ambos semestres. La línea roja discontinua representa la regresión a la media. Observarás que los puntos extremos en el primer semestre tienden a estar más cerca del promedio en el segundo semestre, ilustrando el fenómeno de regresión a la media.
#
# Este ejemplo refleja cómo las observaciones extremas en una medición inicial (calificaciones del primer semestre) tienden a regresar hacia el promedio en mediciones posteriores (calificaciones del segundo semestre) debido a la variabilidad natural y la regresión a la media. Este fenómeno es crucial para comprender las tendencias a largo plazo y evitar interpretaciones sesgadas basadas en mediciones extremas.

# %% [markdown]
# La $Regresión\ a\ la\ media$ es un fenómeno estadístico que implica que las observaciones extremas tienden a ser seguidas por otras más centrales en mediciones sucesivas.
#
# Ejemplo Práctico: Novato del Año en Deportes
#
# - Escenario:
#   - En el mundo deportivo, es común observar el fenómeno del "Novato del Año, declive en segundo año".
#
# - Explicación del Fenómeno:
#   - Primera Temporada:
#     - Supongamos que en una temporada de deporte, varios novatos comienzan sus carreras.
#     - Uno de ellos, el "Novato del Año", destaca y tiene un rendimiento excepcionalmente bueno.
#     - Este rendimiento puede deberse a una combinación de habilidad y suerte.
#
#   - Segunda Temporada:
#     - En la siguiente temporada, este "Novato del Año" puede experimentar un rendimiento menos excepcional.
#     - Razón: La habilidad seguirá presente, pero la suerte que contribuyó al rendimiento destacado en la primera temporada puede no repetirse.
#     - Como resultado, hay una regresión hacia un rendimiento más cercano al promedio.
#
# Ejemplo Conceptual: Altura de Padres e Hijos
#
# - Contexto:
#   - Estamos midiendo la altura de padres e hijos en una población.
#
# - Escenario:
#   - Primera Generación:
#     - Si un padre es excepcionalmente alto, su hijo puede heredar parte de esa altura.
#     - En la primera generación, el hijo puede ser más alto que el promedio debido a la influencia genética del padre.
#
#   - Generaciones Posteriores:
#     - Sin embargo, es probable que el hijo no sea tan extremadamente alto como el padre en las generaciones siguientes.
#     - La altura de los descendientes tiende a regresar hacia el promedio, ya que la variabilidad genética y otros factores influyen en las mediciones.
#
# Importancia en Ciencia de Datos:
#
# - Contexto:
#   - En ciencia de datos, es crucial entender la regresión a la media al interpretar resultados y hacer predicciones.
#
# - Razón:
#   - Cuando se observan valores extremos en un conjunto de datos, es posible que en mediciones futuras esos valores extremos se acerquen al promedio debido a este fenómeno.
#
# - Conclusión:
#   - La regresión a la media destaca la importancia de no sobreinterpretar observaciones extremas y considerar la variabilidad inherente en mediciones sucesivas.
#
# En resumen, la regresión a la media es un fenómeno estadístico fundamental que implica que las observaciones extremas tienden a equilibrarse hacia el promedio en mediciones repetidas, y su comprensión es esencial para una interpretación precisa en el análisis y modelado estadístico.

# %% [markdown]
# ![Captura de pantalla 2024-01-20 004510.png](attachment:69bde681-c0f1-4c8c-bb2e-dd39696ef81a.png)

# %% [markdown]
# **Figura 2-5**. Estudio de Galton que identificó el fenómeno de la regresión a la media

# %% [markdown]
# **Nota:**
#
# La regresión a la media, que significa "volver atrás", es diferente del método de modelado estadístico de la regresión lineal, en el cual se estima una relación lineal entre las variables predictoras y una variable de resultado.

# %% [markdown]
# ### Ideas Clave:
# * Especificar una hipótesis y luego recopilar datos siguiendo los principios de aleatorización y muestreo aleatorio asegura contra el sesgo.
# * Todas las demás formas de análisis de datos corren el riesgo de sesgo resultante del proceso de recopilación/ análisis de datos (ejecución repetida de modelos en minería de datos, fisgoneo de datos en la investigación y selección de eventos interesantes después del hecho).

# %% [markdown]
# ### Lecturas Adicionales:
# * El artículo de Christopher J. Pannucci y Edwin G. Wilkins, "Identifying and Avoiding Bias in Research", en la revista Plastic and Reconstructive Surgery (agosto de 2010), ofrece una excelente revisión de varios tipos de sesgos que pueden entrar en la investigación, incluido el sesgo de selección.
# * El artículo de Michael Harris, "Fooled by Randomness Through Selection Bias", proporciona una revisión interesante de consideraciones de sesgo de selección en esquemas de trading en el mercado de valores, desde la perspectiva de los traders.

# %% [markdown]
# # Distribución de Muestreo de una Estadística
# El término "distribución de muestreo de una estadística" se refiere a la distribución de alguna estadística de muestra sobre muchos conjuntos de muestras extraídas de la misma población. Gran parte de la estadística clásica se ocupa de realizar inferencias desde (pequeñas) muestras hacia (muy grandes) poblaciones.
#
# La Distribución de muestreo de una estadistica es un concepto clave en estadistica que se refiere a la variabilidad que se espera en el valor de una estadística calculada a partir de diferentes muestras de la misma población. Para entender esto, es útil decomponer la definición:
#
# 1. Estadística: En estadísticas, una estadística es cualqueir cantidad calculada a partir de los datos de una muestra. Puede ser la media, la desviación estándar, la porporción, o cualquier otra medida que resuma informacón sobre la muestra.
# 2. Distribución de Muestreo: La distribución de muestreo se refiere a la distribución teórica de los posibles valores de una estadística cuando se calcula a partir de todas las posibles muestras de una población dada. En otras palabras, es una desripción de cómo varia la estadística cunado se toman muestras repetidas de la misma población.
#
# Entonces, la Distribución de muestreo de una estadistica, es esencialmente una herramienta para entender qué tan vairable es una estadistica particular cuandp se calcula a partir de diferentes muestras de la misma población
#
# El concepto es fundamental en inferencia estadística, que es el proceso de hacer afirmaciones o tomar decisiones sobre una población basándose en la información recopilada de una muestra de esa población. Al comprender la distribución de muestreo de un estadística, los estadísticos pueden hacer inferencias más precisas y entender mejor la incertidumbre asociada con sus conclusiones.

# %% [markdown]
# La $Distribución\ muestral$ se relaciona con la variabilidad que se esperaría al calcular una estadística específica a partir de diferentes muestras tomadas de la misma población. Aquí te presentaré algunos ejemplos con la distribución muestral de la media, que es un concepto fundamental.
#
# ### Ejemplo: Distribución Muestral de la Media
#
# Supongamos que estamos interesados en la altura de los estudiantes de una universidad y que la altura real de todos los estudiantes forma una distribución normal con una media de 170 cm y una desviación estándar de 5 cm.
#
# 1. **Población:**
#    - Media poblacional (μ): 170 cm
#    - Desviación estándar poblacional (σ): 5 cm
#
# 2. **Muestra:**
#    - Tomamos múltiples muestras de tamaño $n$ (por ejemplo, $n$ = 30) de la población.
#
# 3. **Estadística de Muestra:**
#    - Calculamos la media $\bar{x}$ de cada muestra.
#
# 4. **Distribución Muestral de la Media:**
#    - La media de la distribución muestral se aproxima a la media poblacional.
#
# ### Ejemplo: Distribución Muestral de la Proporción
#
# Supongamos que estamos interesados en la proporción de estudiantes que aprobaron un examen en una escuela y que la proporción real de aprobados es del 70%.
#
# 1. **Población:**
#    - Proporción poblacional (p): 0.70
#
# 2. **Muestra:**
#    - Tomamos múltiples muestras de tamaño n (por ejemplo, n = 100) de la población.
#
# 3. **Estadística de Muestra:**
#    - Calculamos la proporción de aprobados en cada muestra.
#
# 4. **Distribución Muestral de la Proporción:**
#    - La proporción de la distribución muestral se aproxima a la proporción poblacional.
#
# Estos son ejemplos simplificados, pero muestran cómo la distribución muestral de una estadística, como la media o la proporción, se aproxima a la verdadera medida poblacional a medida que aumentamos el tamaño de la muestra. La distribución muestral es fundamental para realizar inferencias sobre la población basándose en muestras.

# %% [markdown]
# ### Ejemplo: Distribución Muestral de la Media

# %%
# Distribución Muestral de la Media utilizando Python para realizar simulaciones.

import numpy as np
import matplotlib.pyplot as plt

# Parámetros de la población
media_poblacional = 170  # cm
desviacion_estandar_poblacional = 5  # cm
tamano_poblacional = 10000

# Tamaño de la muestra
tamano_muestra = 30

# Número de muestras a tomar
num_muestras = 1000

# Simulación de la distribución muestral de la media
medias_muestrales = []

for _ in range(num_muestras):
    muestra = np.random.normal(media_poblacional, desviacion_estandar_poblacional, tamano_muestra)
    media_muestra = np.mean(muestra)
    medias_muestrales.append(media_muestra)

# Crear un histograma de las medias muestrales
plt.figure(figsize=(10, 6))
plt.hist(medias_muestrales, bins=30, color='skyblue', edgecolor='black')
plt.axvline(x=media_poblacional, color='red', linestyle='dashed', linewidth=2, label='Media poblacional')
plt.xlabel('Media Muestral')
plt.ylabel('Frecuencia')
plt.title('Distribución Muestral de la Media')
plt.legend()
plt.show()

# %% [markdown]
# Este código simula la toma de múltiples muestras de tamaño 30 de una población con una distribución normal de altura de estudiantes. Luego, calcula la media de cada muestra y crea un histograma de las medias muestrales.
#
# Observarás que la distribución de las medias muestrales se aproxima a una distribución normal, independientemente de la forma de la población original. Además, la línea roja punteada representa la media poblacional, mostrando que la media de la distribución muestral se aproxima a la media poblacional.
#
# Este ejemplo ilustra cómo la distribución muestral de la media converge hacia una distribución normal y se centra alrededor de la verdadera media poblacional a medida que se toman más muestras. La Distribución Muestral es esencial para realizar inferencias sobre la población basándose en muestras y proporciona una base para la construcción de intervalos de confianza y pruebas de hipótesis.

# %% [markdown]
# ### Términos Clave para la Distribución de Muestreo
#
# ##### Estadística de muestra
#
# * Una métrica calculada para una muestra de datos extraída de una población más grande.
#
# ##### Distribución de datos
#
# * La distribución de frecuencia de valores individuales en un conjunto de datos.
#
# ##### Distribución de muestreo
#
# * La distribución de frecuencia de una estadística de muestra sobre muchas muestras o remuestras.
#
# ##### Teorema del límite central
#
# * La tendencia de la distribución de muestreo a adquirir una forma normal a medida que aumenta el tamaño de la muestra.
#
# ##### Error estándar
#
# * La variabilidad (desviación estándar) de una estadística de muestra sobre muchas muestras (no debe confundirse con la desviación estándar, que por sí sola se refiere a la variabilidad de valores individuales de datos).

# %% [markdown]
# Por lo general, se extrae una muestra con el objetivo de medir algo (con una estadística de muestra) o modelar algo (con un modelo estadístico o de aprendizaje automático). Dado que nuestra estimación o modelo se basa en una muestra, podría contener errores; podría ser diferente si extrajéramos una muestra diferente. Por lo tanto, nos interesa cuán diferente podría ser; una preocupación clave es la variabilidad de muestreo. Si tuviéramos muchos datos, podríamos extraer muestras adicionales y observar directamente la distribución de una estadística de muestra. Por lo general, calcularemos nuestra estimación o modelo utilizando la mayor cantidad de datos disponible de manera fácil, por lo que la opción de extraer muestras adicionales de la población no está fácilmente disponible.

# %% [markdown]
# **Nota:**
#
# Es importante distinguir entre la distribución de los puntos de datos individuales, conocida como la distribución de datos, y la distribución de una estadística de muestra, conocida como la distribución de muestreo.
#
# La distinción entre la dsitribución de datos y la distribución de muestreo es crucial en estadísticas y ciencia de datos.
#
# 1. **Distribución de Datos:**
#
#    - La distribución de datos se refiere a cómo están dispersos o agrupados los puntos de datos individuales en un conjunto de datos.
#    - Incluye características como la forma de la distribución, la dispersión de los datos alrededor de la media, la presencia de valores atípicos, etc.
#    - Se centra en describir la variabilidad y la estructura de los datos observados en un conjunto en particular.
#    - Ejemplos de distribuciones de datos incluyen la distribución normal, distribuciones sesgadas, distribuciones uniformes, entre otras.
#
# 2. **Distribución de Muestreo:**
#
#    - La distribución de muestreo se refiere a la distribución de las estadísticas calculadas a partir de diferentes muestras tomadas de la misma población.
#    - Implica tomar múltiples muestras de la población, calcular la estadística de interés en cada muestra y examinar cómo varian esas estadisticas.
#    - La distribución de uestreo es fundamental para realizar inferencias sobre la población basándose en las muestras.
#    - Ejemplos de distribuciones de muestreo incluyen la distribución muestral de la media, distribución muestral de la porporción, etc.
#
# En resumen, la distribución de datos se refiere a cómo se agrupan o dispersan los valores individuales en un conjunto de datos especificos, miestras que la distribucion de muestreo se refiere a como varian las estadisticas calculadas a partir de diferentes muestras de la misma población. La primera se ocupa de los valores observados, miestras que la segunda se centra en la variabilidad de las estadisticas calculadas a partir de esas muestras. Ambos conceptos son esenciales para realizar inferencias y generalizar conclusiones sobre poblaciones basándose en muestras.

# %% [markdown]
# La distribución de una estadística de muestra, como la media, es probable que sea más regular y en forma de campana que la distribución de los datos en sí. Esto es más evidente a medida que aumenta el tamaño de la muestra en la que se basa la estadística. Además, cuanto mayor sea la muestra, más estrecha será la distribución de la estadística de muestra.
#
# Esto se ilustra en un ejemplo que utiliza los ingresos anuales de solicitantes de préstamos a LendingClub (consulte "Un Pequeño Ejemplo: Predicción de Incumplimiento de Préstamos" en la página 239 para obtener una descripción de los datos). Tome tres muestras de estos datos: una muestra de 1,000 valores, una muestra de 1,000 medias de 5 valores y una muestra de 1,000 medias de 20 valores. Luego, grafique un histograma de cada muestra para producir la Figura 2-6.

# %% [markdown]
# ![Captura de pantalla 2024-01-20 005019.png](attachment:fb1a5bb3-2231-45a6-8509-46a33262b05a.png)

# %% [markdown]
# **Figura 2-6**. Histograma de los ingresos anuales de 1,000 solicitantes de préstamos (arriba), luego 1,000 medias de $n=5$ solicitantes (en el medio), y finalmente 1,000 medias de $n=20$ solicitantes (abajo).

# %% [markdown]
# El histograma de los valores individuales de los datos está ampliamente distribuido y sesgado hacia valores más altos, como era de esperar con datos de ingresos. Los histogramas de las medias de 5 y 20 son cada vez más compactos y tienen una forma de campana más pronunciada. Aquí está el código R para generar estos histogramas, utilizando el paquete de visualización ggplot2:

# %% [markdown]
#     library(ggplot2)
#     # take a simple random sample
#     samp_data <- data.frame(income=sample(loans_income, 1000),
#      type='data_dist')
#     # take a sample of means of 5 values
#     samp_mean_05 <- data.frame(
#      income = tapply(sample(loans_income, 1000*5),
#      rep(1:1000, rep(5, 1000)), FUN=mean),
#      type = 'mean_of_5')
#     # take a sample of means of 20 values
#     samp_mean_20 <- data.frame(
#      income = tapply(sample(loans_income, 1000*20),
#      rep(1:1000, rep(20, 1000)), FUN=mean),
#      type = 'mean_of_20')
#     # bind the data.frames and convert type to a factor
#     income <- rbind(samp_data, samp_mean_05, samp_mean_20)
#     income$type = factor(income$type,
#      levels=c('data_dist', 'mean_of_5', 'mean_of_20'),
#      labels=c('Data', 'Mean of 5', 'Mean of 20'))
#     # plot the histograms
#     ggplot(income, aes(x=income)) +
#      geom_histogram(bins=40) +
#      facet_grid(type ~ .)

# %% [markdown]
# El código en Python utiliza el FacetGrid de seaborn para mostrar los tres histogramas:

# %%
import pandas as pd
import seaborn as sns

# %%
# Crear un DataFrame llamado "sample_data" con 1000 valores aleatorios de 
#la Serie "loans_income" en la columna 'income' y la etiqueta 'Data' en la columna 'type'.
sample_data = pd.DataFrame({
    "income": loans_income.sample(1000),
    "type": "Data",
})

# Crear un DataFrame llamado "sample_mean_05" con 1000 valores, cada uno
#siendo la media de 5 valores aleatorios de la Serie "loans_income" y etiquetado como 'Mean of 5'.
sample_mean_05 = pd.DataFrame({
    "income": [loans_income.sample(5).mean() for _ in range(1000)],
    "type": "Mean of 5",
})

# Crear un DataFrame llamado "sample_mean_20" con 1000 valores, cada 
#uno siendo la media de 20 valores aleatorios de la Serie "loans_income" y etiquetado como 'Mean of 20'.
sample_mean_20 = pd.DataFrame({
    "income": [loans_income.sample(20).mean() for _ in range(1000)],
    "type": "Mean of 20",
})

# Concatenar los DataFrames "sample_data", "sample_mean_05" y "sample_mean_20"
#a lo largo de las filas y almacenar el resultado en un nuevo DataFrame llamado "results".
results = pd.concat([sample_data, sample_mean_05, sample_mean_20])

# Crear un objeto FacetGrid de Seaborn llamado "g" que utilizará el DataFrame "results". 
# Los subgráficos se organizarán en columnas según la columna 'type' del DataFrame.
# Se establece que habrá 1 subgráfico por columna, con una altura de 2 unidades y 
#una relación de aspecto de 2.
g = sns.FacetGrid(results, col="type", col_wrap=1, height=2, aspect=2)

# Mapear un histograma en cada subgráfico utilizando la columna 'income' 
#del DataFrame "results".
# Se especifica el rango de valores [0, 200000] y se dividen los datos en
#40 contenedores (bins).
g.map(plt.hist, "income", range=[0, 200000], bins=40)

# Establecer etiquetas de ejes para los subgráficos. El eje x se etiqueta como
#"Income" y el eje y como "Count".
g.set_axis_labels("Income", "Count")

# Establecer los títulos de los subgráficos utilizando los nombres de las columnas
#'type' del DataFrame.
g.set_titles("{col_name}")
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Teorema del Límite Central
# El fenómeno que acabamos de describir se denomina el teorema del límite central. *Este teorema establece que las medias obtenidas de múltiples muestras se asemejarán a la conocida curva normal en forma de campana* (consulte "Distribución Normal" en la página 69), incluso si la población fuente no sigue una distribución normal, siempre que el tamaño de la muestra sea lo suficientemente grande y la desviación de la normalidad de los datos no sea demasiado grande. El teorema del límite central permite utilizar fórmulas de aproximación normal, como la distribución t, en el cálculo de distribuciones de muestreo para inferencias, es decir, intervalos de confianza y pruebas de hipótesis.
#
# Aunque el teorema del límite central recibe mucha atención en los textos de estadísticas tradicionales porque subyace en los mecanismos de las pruebas de hipótesis y los intervalos de confianza, que ocupan la mitad del espacio en tales textos, los científicos de datos deben ser conscientes de que este papel es menos relevante en la práctica de la ciencia de datos. Las pruebas de hipótesis formales y los intervalos de confianza juegan un papel secundario en la ciencia de datos, y el bootstrap (consulte "El Bootstrap" en la página 61) está disponible de todos modos, por lo que el teorema del límite central no es tan central en la práctica de la ciencia de datos.
#
# El $Teorema\ del\ Límite\ Central$ es un principio fundamental en estadística que describe el comportamiento de las medias de muestras extraídas de una población, inckuso si la distribución original de la población no es normal. Aquí se explica el contanido del comentario:
#
# 1. Definición del teorema del límite central:
#
#    - Este teorema establece que, cuando se toman múltiples muestras de una población y se calcula la media de cada muestra, la distribución de esas medias se asemejará a una distribución normal, independientemnete de la forma de la distribución original de la población. Esto es válido siempre que el tamaño de la muestra sea lo suficientemente grande y la desviación de la normalidad no se excesiva.
#
# 2. Utilidad del teorema del límite central:
#
#    - El teorema del límite central es esencial porque permite utilizar fórmulas de aproximación normal, como la distribución t, en el cálculo de distribuciones de muestreo para realizar inferencias estadísticas. Esto incluye la construcción de intervalos de confianza y la realización de pruebas de hpótesis.
#
# 3. Importancia en la Ciencia de Datos:
#
#    - Se señala que, aunque el teorema del límite central es central en la estadística tradicional, en la práctica de la ciencia de datos su papel es menos relevante. Las pruebas de hpótesis y los intervalos de confianza, que dependen del teorema del límite central, juegan un papel secundario en la ciencia de datos. Además, se menciona que el bootstrap, una técnica de remuestreo, está disponible y a menudo es preferido en la práctica de la ciencia de datos. Por lo tanto, el teorema del límite central no es tan central en la ciencia de datos como en otros enfoques estadísticos más tradicionales.

# %% [markdown]
# ### Teorema del Límite Cental: Explicación con Ejemplo
#
# El teorema del límite central es una principio fundamental en estadística que describe coómo se comportan las medias de mútiples muestras, incluso se la población original no sigue una distribución normal.
#
# ### Ejemplo: Altura de Estudiantes
# Supongamos que estamos interesados en la altura de todos los estudiantes de una universidad. La altura real de todos los estudiantes en la Universidad forma una distribución original que podría no ser perfectamente normal.
#
# 1. Teorema del Límite Cnetral:
#
#    - El teorema dice que si tomamos múltiples muestras de estudiantes y calculamos la altura promedio en cada muestra, la distribución de esas alturas promedio se asemejara a una distribución normal, independientemente de la forma original de la distribución de alturas individuales.
#    - Ejercicio Práctico:
#        - Tomamos varias muestras de diferentes tamaños de estudiantes.
#        - Calculamos la altura promedio en cada muestra.
#    - Resultados Esperados:
#        - Según el teorema del límite central, aunque la distribución de alturas individuales puede ser sesgada o no normal, la distribución de las alturas promedio de las muestras será más parecida a una distribución normal a medida que aumentamos el tamaño de la muestra.

# %% [markdown]
# ### Ejemplo: Teorema del Límite Central

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros de la población (distribución no normal)
np.random.seed(42)
altura_poblacion = np.random.exponential(170, 10000)  # Alturas de estudiantes
#(distribución no normal)

# Tamaños de muestra a considerar
tamanos_muestra = [30, 50, 100]

# Número de simulaciones
num_simulaciones = 1000

# Simulación del Teorema del Límite Central
plt.figure(figsize=(6, 6))

for tamano_muestra in tamanos_muestra:
    medias_muestrales = []

    for _ in range(num_simulaciones):
        muestra = np.random.choice(altura_poblacion, size=tamano_muestra, replace=False)
        media_muestra = np.mean(muestra)
        medias_muestrales.append(media_muestra)

    # Crear un histograma de las medias muestrales
    plt.hist(medias_muestrales, bins=30, alpha=0.6,
             label=f'Tamaño de Muestra: {tamano_muestra}')

# Agregar una línea vertical para la media poblacional
media_poblacional = np.mean(altura_poblacion)
plt.axvline(x=media_poblacional, color='red', linestyle='dashed', linewidth=2,
            label='Media Poblacional')

plt.xlabel('Altura Promedio de la Muestra')
plt.ylabel('Frecuencia')
plt.title('Teorema del Límite Central: Altura de Estudiantes')
plt.legend()
plt.show()

# %% [markdown]
# Este código simula la toma de múltiples muestras de diferentes tamaños de alturas de estudiantes. Aunque la distribución original de alturas individuales no sigue una distribución normal (se utiliza una distribución exponencial para simular esto), observarás que la distribución de las alturas promedio de las muestras se asemeja cada vez más a una distribución normal a medida que aumentamos el tamaño de la muestra, lo cual es un reflejo del Teorema del Límite Central.
#
# La línea roja punteada en el gráfico representa la media poblacional, y puedes observar cómo las medias de las muestras se centran alrededor de esta media poblacional a medida que el tamaño de la muestra aumenta. Esto es consistente con la idea del Teorema del Límite Central, que establece que la distribución de las medias de las muestras se aproxima a una distribución normal independientemente de la forma de la distribución original a medida que aumentamos el tamaño de la muestra.

# %% [markdown]
# # Error Estándar
# El error estándar es una única métrica que resume la variabilidad en la distribución de muestreo para una estadística. El error estándar se puede estimar utilizando una estadística basada en la desviación estándar $s$ de los valores de la muestra y el tamaño de la muestra $n$:
# $$Error\ estándar = EE = \frac{s}{\sqrt{n}}$$
#
# A medida que aumenta el tamaño de la muestra, el error estándar disminuye, lo cual se corresponde con lo observado en la Figura 2-6. La relación entre el error estándar y el tamaño de la muestra a veces se denomina la regla de la raíz cuadrada de n: para reducir el error estándar en un factor de 2, el tamaño de la muestra debe aumentarse en un factor de 4.
#
# La validez de la fórmula del error estándar se deriva del teorema del límite central. De hecho, no es necesario depender del teorema del límite central para entender el error estándar. Considera el siguiente enfoque para medir el error estándar:
#
# 1. Recolecta una cantidad de muestras completamente nuevas de la población.
# 2. Para cada muestra nueva, calcula la estadística (por ejemplo, la media).
# 3. Calcula la desviación estándar de las estadísticas calculadas en el paso 2; utiliza esto como tu estimación del error estándar.
#
# En la práctica, este enfoque de recolección de nuevas muestras para estimar el error estándar generalmente no es factible (y estadísticamente muy derrochador). Afortunadamente, resulta que no es necesario extraer muestras completamente nuevas; en su lugar, puedes usar remuestreos bootstrap. En estadísticas modernas, el bootstrap se ha convertido en la forma estándar de estimar el error estándar. Puede utilizarse virtualmente para cualquier estadística y no depende del teorema del límite central ni de otras suposiciones de distribución.

# %% [markdown]
# ### Error Estándar: Concepto y Fórmula
#
# El $Error\ Estándar$ es una medida que resume cuánto varían las estadísticas de muestreo alrededor de su valor real en la población. Es útil para comprender cuán precisas son nuestras estimaciones basadas en muestras.
#
# 1. **Fórmula del Error Estándar:**
#
#    - La fórmula del error estándar se calcula usando la desviación estándar de la muestra ($s$) y el tamaño de la muestra ($n$):
#    $$Error\ estándar = EE = \frac{s}{\sqrt{n}}$$
#
# 2. **Interpretación:**
#
#    - Cuanto menor sea el error estándar, más precisa será nuestra estimación. Este valor resume cuánta variabilidad podemos esperar en nuestras estimaciones debido a la aleatoridad de las muestras.
#
# 3. **Relación con el Tamaño de la muestra:**
#
#    - A medida que aumenta el tamaño de la muestra $n$, el error estándar disminuye. Esto significa que con muestras más grandes, nuestras estimaciones son más precisas y consistentes.
#
# ### Ejemplo:
#
# Supongamos que estamos midiendo la altura de estudiantes en una escuela y queremos estimar la altura promedio en la población. Tomamos varias muestras de diferentes tamaños y calculamos el error estándar.
#
# - Si tenemos una muestra pequeña ( pocos estudiantes), el error estándar puese ser relativamente grande, lo que indic que nuestras estimaciones pueden variar significativamente de una muestra a otra.
# - Si tenemos una muestra grande ( mucgas cantidades de estudiantes), el error estándar srpa más pequeño, sugiriendo que nuestras estimaciones son más confiables y tienden a acercarse más a la verdadera altura promedio en la población.
#
# En resumen, el error estándar nos ayuda a entender cuán confiables son nuestras estimaciones basadas en muestras, y su relación con el tamaño de la muestra, nos muestra la importancia de recopilar datos suficientes para obtener estimaciones más precisas.

# %% [markdown]
# ### Ejemplo: Error Estándar

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros de la población
np.random.seed(42)
altura_poblacional = np.random.normal(170, 5, 10000)  # Alturas de estudiantes
#(distribución normal)

# Tamaños de muestra a considerar
tamanos_muestra = [10, 30, 50, 100]

# Número de simulaciones
num_simulaciones = 1000

# Calcularemos el error estándar para cada tamaño de muestra
errores_estandar = []

for tamano_muestra in tamanos_muestra:
    errores_simulacion = []

    for _ in range(num_simulaciones):
        muestra = np.random.choice(altura_poblacional, size=tamano_muestra,
                                   replace=False)
        error_estandar = np.std(muestra, ddof=1) / np.sqrt(tamano_muestra)
        errores_simulacion.append(error_estandar)

    errores_estandar.append(errores_simulacion)

# Crear un gráfico de cajas para comparar los errores estándar
plt.figure(figsize=(6, 6))
plt.boxplot(errores_estandar, labels=[f"Tamaño {tamano}" for tamano in tamanos_muestra])
plt.title('Error Estándar para Diferentes Tamaños de Muestra')
plt.xlabel('Tamaño de Muestra')
plt.ylabel('Error Estándar')
plt.show()

# %% [markdown]
# Este código simula la toma de múltiples muestras de alturas de estudiantes de una población con distribución normal. Luego, calcula el error estándar para cada tamaño de muestra y compara los resultados visualmente utilizando un gráfico de cajas.
#
# Observarás que a medida que aumenta el tamaño de la muestra, el error estándar tiende a disminuir. Esto refleja la relación inversa entre el tamaño de la muestra y la precisión de la estimación. Con un tamaño de muestra más grande, el error estándar es más pequeño, indicando que las estimaciones son más precisas y consistentes. Este ejemplo ilustra cómo el error estándar puede utilizarse para evaluar la precisión de nuestras estimaciones basadas en muestras y cómo esta precisión mejora con muestras más grandes.

# %% [markdown]
# **Nota:**
#
# No confundas la desviación estándar (que mide la variabilidad de los puntos de datos individuales) con el error estándar (que mide la variabilidad de una métrica de muestra).

# %% [markdown]
# ### Ideas Clave:
# * La distribución de frecuencia de una estadística de muestra nos indica cómo esa métrica podría variar de una muestra a otra.
# * Esta distribución de muestreo puede estimarse mediante el bootstrap o mediante fórmulas que dependen del teorema del límite central.
# * Una métrica clave que resume la variabilidad de una estadística de muestra es su error estándar.

# %% [markdown]
# ### Lecturas Adicionales
# El recurso multimedia en línea de estadísticas de David Lane tiene una simulación útil que te permite seleccionar una estadística de muestra, un tamaño de muestra y el número de iteraciones, y visualizar un histograma de la distribución de frecuencia resultante.

# %% [markdown]
# # El Bootstrap
# Una manera fácil y efectiva de estimar la distribución de muestreo de una estadística o de los parámetros de un modelo es extraer muestras adicionales, con reemplazo, de la muestra misma y recalcular la estadística o el modelo para cada remuestreo. Este procedimiento se llama bootstrap y no necesariamente implica ninguna suposición sobre la normalidad de los datos o de la estadística de muestra.

# %% [markdown]
# ### El Bootstrap: Estimación de la Distribución de muestreo sin suposiciones específicas
#
# - El $Bootstrap$ es un método estadístico que proporciona una manera fácil y efectiva de estimar la distribución de muestreo de una estadística o los parámetros de un modelo. Este proceso implica extraer muestras adicionales, con reemplazo, de la muestra original y recalcular la estadística o el modelo para cada remestreo.
#
# **Pasos del Bootstrap:**
#
# 1. Muestra Inicial:
#    - Comienza con una muestra de datos inicial que representa la población de interés.
# 2. Remuestreo con Reemplazo:
#    - Se extraen muestras adicionales de la muestra inicial, y cada observación tiene la posibilidad de ser seleccionada en múltiples remuestreos debido al reemplazo.
# 3. Recálculo de Estadísticas o Parámetros:
#    - Para cada remuestreo, se recalcula la estadística de interés o los parámetros del modelo.
# 4. Construcción de Distribución de Muestreo:
#    - Se construye una distribución de muestreo utilizando las estadísticas o parametros calculados en los remuestreos.

# %% [markdown]
# **Características Clave del Bootstrap:**
# - **Muestreo con Reemplazo:**
#   - Las muestras adicionales se extraen de la muestra original, y cada observación tiene la posibilidad de ser seleccionada en múltiples remuestreos debido al reemplazo.
#
# - **Estimación de Distribución de Muestreo:**
#   - El objetivo principal es obtener una estimación de la distribución de muestreo de una estadística o de los parámetros de un modelo sin hacer suposiciones específicas sobre la distribución subyacente de los datos.
#
# **Ventajas del Bootstrap:**
# - **Sin Suposiciones Duras:**
#   - No requiere asumir una forma específica de distribución de datos.
#
# - **Universalmente Aplicable:**
#   - Puede aplicarse a casi cualquier estadística o modelo, incluso cuando no se conoce la distribución subyacente.
#
# - **Robusto y Efectivo:**
#   - Es una técnica robusta y efectiva para obtener intervalos de confianza y estimaciones puntuales.
#
# **Importancia en la Ciencia de Datos:**
# - **Práctica Común:**
#   - En la ciencia de datos, el bootstrap es una herramienta comúnmente utilizada para evaluar la variabilidad de estimaciones y para construir intervalos de confianza.
#
# - **Flexibilidad:**
#   - Ofrece flexibilidad al no depender de suposiciones específicas sobre la población subyacente.
#
# **Ejemplo de Aplicación:**
# - Supongamos que estamos interesados en estimar la media de una variable en una población.
#   - En lugar de hacer suposiciones sobre la distribución de la población, podríamos aplicar el bootstrap.
#   - Extraemos muestras adicionales de nuestros datos, con reemplazo, y calculamos la media para cada remuestreo.
#   - Al repetir este proceso, obtenemos una distribución de muestreo de la media sin asumir nada sobre la forma de la población.
#
# **Conclusión:**
# - El bootstrap es una herramienta valiosa en la caja de herramientas de un científico de datos, ya que proporciona una forma práctica y flexible de abordar la variabilidad en las estimaciones sin depender de suposiciones específicas.

# %% [markdown]
# ### Ejemplo: Método Bootstrap

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de alturas de estudiantes (ejemplo simplificado)
np.random.seed(42)
altura_muestra = np.random.normal(170, 5, 100)  # Muestra de alturas (distribución normal)

# Función para realizar bootstrap
def bootstrap_sample(data, num_samples=1000):
    bootstrap_means = []

    for _ in range(num_samples):
        bootstrap_sample = np.random.choice(data, size=len(data), replace=True)
        bootstrap_mean = np.mean(bootstrap_sample)
        bootstrap_means.append(bootstrap_mean)

    return bootstrap_means

# Realizar bootstrap en la muestra de alturas
bootstrap_means = bootstrap_sample(altura_muestra)

# Calcular el intervalo de confianza del 95%
intervalo_confianza = np.percentile(bootstrap_means, [2.5, 97.5])

# Crear un histograma de las medias bootstrap
plt.figure(figsize=(6, 6))
plt.hist(bootstrap_means, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(x=np.mean(altura_muestra), color='red', linestyle='dashed', linewidth=2, label='Media de la Muestra')
plt.axvline(x=intervalo_confianza[0], color='green', linestyle='dashed', linewidth=2, label='Intervalo de Confianza (95%)')
plt.axvline(x=intervalo_confianza[1], color='green', linestyle='dashed', linewidth=2)
plt.xlabel('Altura Media Bootstrap')
plt.ylabel('Frecuencia')
plt.title('Bootstrap para Estimar la Media de Alturas de Estudiantes')
plt.legend()
plt.show()

print(f"Media de la muestra: {np.mean(altura_muestra):.2f}")
print(f"Intervalo de confianza (95%): {intervalo_confianza}")
# Out:
# Media de la muestra: 169.48
# Intervalo de confianza (95%): [168.63831788 170.31425743]

# %% [markdown]
# En este ejemplo, hemos generado una muestra de alturas de estudiantes y luego hemos realizado bootstrap para estimar la distribución de muestreo de la media de altura. El intervalo de confianza del 95% se calcula a partir de los percentiles 2.5 y 97.5 de las medias bootstrap.
#
# Observarás en el gráfico que la distribución de las medias bootstrap se asemeja a una distribución normal, y el intervalo de confianza del 95% proporciona una estimación de la variabilidad de la media de altura.
#
# Este procedimiento de bootstrap es útil cuando queremos estimar la distribución de muestreo de una estadística sin hacer suposiciones específicas sobre la forma de la población original y es una herramienta poderosa en estadísticas inferenciales.

# %% [markdown]
# ### Términos clave para el Bootstrap
#
# #### Muestra bootstrap
# * Una muestra tomada con reemplazo de un conjunto de datos observado.
#
# #### Remuestreo
# * El proceso de tomar muestras repetidas de datos observados; incluye tanto los procedimientos de bootstrap como de permutación (barajado).

# %% [markdown]
# Conceptualmente, puedes imaginarte el bootstrap como la replicación de la muestra original miles o millones de veces, de manera que tengas una población hipotética que incorpora todo el conocimiento de tu muestra original (simplemente es más grande). Luego, puedes extraer muestras de esta población hipotética con el propósito de estimar una distribución de muestreo; consulta la Figura 2-7.

# %% [markdown]
# ![Captura de pantalla 2024-01-21 152957.png](attachment:12a7cb2c-e390-42bf-a284-3048b866f7ff.png)

# %% [markdown]
# **Figura 2-7**. La idea del bootstrap

# %% [markdown]
# En la práctica, no es necesario replicar la muestra un gran número de veces. Simplemente reemplazamos cada observación después de cada selección; es decir, hacemos un muestreo con reemplazo. De esta manera, creamos efectivamente una población infinita en la que la probabilidad de que un elemento sea seleccionado no cambia de una selección a otra. El algoritmo para un remuestreo bootstrap de la media, para una muestra de tamaño n, es el siguiente:
#
# 1. Selecciona un valor de la muestra, regístralo y luego reemplázalo.
# 2. Repite n veces.
# 3. Registra la media de los n valores remuestreados.
# 4. Repite los pasos 1-3 R veces.
# 5. Utiliza los resultados de R para:
#    a. Calcular su desviación estándar (esto estima el error estándar de la media de la muestra).
#    b. Producir un histograma o un diagrama de cajas.
#    c. Encontrar un intervalo de confianza.
#
# R, el número de iteraciones del bootstrap, se elige de manera algo arbitraria. Cuantas más iteraciones hagas, más precisa será la estimación del error estándar o el intervalo de confianza. El resultado de este procedimiento es un conjunto bootstrap de estadísticas de muestra o parámetros del modelo estimados, que luego puedes examinar para ver cuán variables son.
#
# El paquete R "boot" combina estos pasos en una función. Por ejemplo, lo siguiente aplica el bootstrap a los ingresos de las personas que solicitan préstamos:

# %% [markdown]
#     library(boot)
#     stat_fun <- function(x, idx) median(x[idx])
#     boot_obj <- boot(loans_income, R=1000, statistic=stat_fun)

# %% [markdown]
# La función `stat_fun` calcula la mediana para una muestra dada especificada por el índice `idx`. El resultado es el siguiente:

# %% [markdown]
#     Bootstrap Statistics :
#      original bias std. error
#     t1* 62000 -70.5595 209.1515

# %% [markdown]
# La estimación original de la mediana es de $62,000. La\ distribución\ bootstrap\ indica\ que\ la\ estimación\ tiene\ un\ sesgo\ de\ aproximadamente\ -$70 y un error estándar de $209. Los resultados variarán ligeramente entre ejecuciones consecutivas del algoritmo.
# Las principales bibliotecas de Python no proporcionan implementaciones del enfoque bootstrap. Se puede implementar utilizando el método `resample` de scikit-learn:

# %%
# Crear una lista llamada "results" para almacenar las estadísticas bootstrap.
results = []

# Realizar el procedimiento de bootstrap 1000 veces.
for nrepeat in range(1000):
    # Resample (muestrear con reemplazo) la Serie "loans_income".
    sample = resample(loans_income)
    
    # Calcular la mediana de la muestra y agregarla a la lista "results".
    results.append(sample.median())

# Convertir la lista "results" en una Serie de pandas.
results = pd.Series(results)

# Imprimir estadísticas bootstrap.
print("Bootstrap Statistics:")

# Imprimir la mediana original de la Serie "loans_income".
print(f"original: {loans_income.median()}")

# Imprimir el sesgo (bias) calculado como la media de las estadísticas bootstrap menos la mediana original.
print(f"bias: {results.mean() - loans_income.median()}")

# Imprimir el error estándar de las estadísticas bootstrap.
print(f"std. error: {results.std()}")
# Out:
# Bootstrap Statistics:
# original: 62000.0
# bias: -89.85650000000169
# std. error: 233.34343855799503

# %% [markdown]
# El bootstrap se puede utilizar con datos multivariados, donde las filas se muestrean como unidades (ver Figura 2-8). Posteriormente, se podría ejecutar un modelo en los datos remuestreados, por ejemplo, para estimar la estabilidad (variabilidad) de los parámetros del modelo o para mejorar el poder predictivo. Con árboles de clasificación y regresión (también llamados árboles de decisión), ejecutar múltiples árboles en muestras bootstrap y luego promediar sus predicciones (o, en el caso de la clasificación, tomar un voto mayoritario) generalmente produce mejores resultados que usar un solo árbol. Este proceso se llama bagging (abreviatura de "bootstrap aggregating"; ver "Bagging and the Random Forest" en la página 259).

# %% [markdown]
# ![Captura de pantalla 2024-01-21 153719.png](attachment:5d522d96-1024-442b-b0c9-610ac2b25692.png)

# %% [markdown]
# **Figura 2-8**. Muestreo bootstrap multivariado

# %% [markdown]
# El remuestreo repetido del bootstrap es conceptualmente simple y Julian Simon, un economista y demógrafo, publicó un compendio de ejemplos de remuestreo, incluido el bootstrap, en su texto de 1969 "Basic Research Methods in Social Science" (Random House). Sin embargo, también es intensivo en términos computacionales y no era una opción factible antes de la amplia disponibilidad de la potencia informática. La técnica adquirió su nombre y se popularizó con la publicación de varios artículos en revistas y un libro del estadístico de Stanford Bradley Efron a finales de la década de 1970 y principios de la década de 1980. Fue particularmente popular entre los investigadores que utilizan estadísticas pero no son estadísticos, y para su uso con métricas o modelos donde las aproximaciones matemáticas no están fácilmente disponibles. La distribución de muestreo de la media ha estado bien establecida desde 1908; la distribución de muestreo de muchas otras métricas no lo ha estado. El bootstrap se puede utilizar para determinar el tamaño de la muestra; experimenta con diferentes valores para n para ver cómo se ve afectada la distribución de muestreo.
#
# El bootstrap fue recibido con considerable escepticismo cuando se introdujo por primera vez; para muchos, tenía la apariencia de convertir paja en oro. Este escepticismo se debió a una malinterpretación del propósito del bootstrap.

# %% [markdown]
# **Nota:**
#
# El bootstrap no compensa un tamaño de muestra pequeño; no crea nuevos datos ni rellena huecos en un conjunto de datos existente. Simplemente nos informa sobre cómo se comportarían muchas muestras adicionales al extraerse de una población similar a nuestra muestra original.

# %% [markdown]
# # Resampling Versus Bootstrapping
#
# En ocasiones, el término "resampling" se utiliza de manera sinónima con el término "bootstrapping", tal como se describió anteriormente. Con mayor frecuencia, el término "resampling" también incluye procedimientos de permutación (ver "Permutation Test" en la página 97), donde se combinan múltiples muestras y el muestreo puede realizarse sin reemplazo. En cualquier caso, el término "bootstrap" siempre implica realizar un muestreo con reemplazo de un conjunto de datos observados.

# %% [markdown]
# ### Resampling Versus Bootstrapping: Diferencias y Relaciones
#
# #### Resampling:
#
# **Definición General:** Resampling es un término que se refiere a la técnica de tomar múltiples muestras de datos con el objetivo de realizar inferencias estadísticas o evaluar la variabilidad de las estimaciones.
# * Incluye Diversas Técnicas: Es un sentido más amplio, el resampling puede abarcar varias técnicas, no solo el bootstrapping. Puede incluir métodos como la permutación, donde se combinan múltiples muestras y el muestreo puede realizarse con o sin reemplazo.
#
# #### Bootstrapping:
#
# **Definición Específica:** Bootstrapping es una técnica especifica de resampling que implica extraer muestras adicionales, con reemplazo, de la muestra original para estimar la distribución de muestreo de una estadística o parámetro.
# * Siempre Involucra Reemplazo: En el contexto del bootstrap, el muestreo siempre se realiza con reemplazo, lo que significa que una observación puede ser seleccionada en mpultiples remuestreos.
#
# **Conclusión:**
#
# Mientras que "resampling" es un término más general que abarca diversas técnicas de toma de muestras, el "bootstrapping" es una forma específica de resampling que siempre implica el muestreo con reemplazo. La distinción entre los términos radica en la amplitud de técnicas que pueden incluirse bajo el resampling, mientras que el bootstrap se centra en la repetición con reemplazo para estimar distribuciones de muestreo.

# %% [markdown]
# ### Ideas claves
# * El bootstrap (muestreo con reemplazo de un conjunto de datos) es una herramienta poderosa para evaluar la variabilidad de una estadística de muestra.
# * El bootstrap se puede aplicar de manera similar en una amplia variedad de circunstancias, sin un estudio extenso de aproximaciones matemáticas a las distribuciones de muestreo.
# * También nos permite estimar distribuciones de muestreo para estadísticas donde no se ha desarrollado ninguna aproximación matemática.
# * Cuando se aplica a modelos predictivos, la agregación de múltiples predicciones de muestras bootstrap (bagging) supera el uso de un solo modelo.

# %% [markdown]
# ### Lectura recomendada
# * "An Introduction to the Bootstrap" by Bradley Efron and Robert Tibshirani (Chapman & Hall, 1993) fue el primer tratamiento en formato de libro sobre el bootstrap. Todavía se lee ampliamente.
# * La retrospectiva sobre el bootstrap en el número de mayo de 2003 de Statistical Science (vol. 18, no. 2), discute (entre otros antecedentes, en el artículo de Peter Hall "A Short Prehistory of the Bootstrap") la publicación inicial del bootstrap por Julian Simon en 1969.
# * Consulta "An Introduction to Statistical Learning" de Gareth James, Daniela Witten, Trevor Hastie y Robert Tibshirani (Springer, 2013) para secciones sobre el bootstrap y, en particular, bagging.

# %% [markdown]
# # Intervalos de Confianza
# Tablas de frecuencia, histogramas, diagramas de caja (boxplots) y errores estándar son todas formas de entender el error potencial en una estimación de muestra. Los intervalos de confianza son otro método.

# %% [markdown]
# **Concepto General:**
# - Los *intervalos de confianza* son una herramienta estadística que proporciona una medida de la incertidumbre asociada con una estimación de muestra. En lugar de proporcionar una única estimación puntual, los intervalos de confianza ofrecen un rango dentro del cual es probable que se encuentre el verdadero parámetro poblacional.
#
# **Comparación con Otras Formas de Entender el Error:**
# - **Tablas de Frecuencia, Histogramas y Boxplots:**
#   - Estas representaciones visuales ayudan a comprender la distribución de los datos y la variabilidad en las observaciones de muestra.
#
# - **Errores Estándar:**
#   - Los errores estándar miden la variabilidad de una estadística de muestra y proporcionan información sobre qué tan típicamente varía la estadística de una muestra a otra.
#
# **Funcionamiento de los Intervalos de Confianza:**
# - **Probabilidad de Contener el Parámetro Poblacional:**
#   - Un intervalo de confianza indica un rango dentro del cual es probable que se encuentre el verdadero parámetro poblacional. Por ejemplo, un intervalo de confianza del 95% significa que, en teoría, el 95% de los intervalos calculados de la misma manera contendrían el verdadero valor del parámetro.
#
# **Importancia en Estadísticas:**
# - **Medida de Incertidumbre:**
#   - Los intervalos de confianza son esenciales porque reconocen la incertidumbre inherente a las estimaciones de muestra. Proporcionan una manera de cuantificar esta incertidumbre y ofrecen una visión más completa que una estimación puntual única.
#
# - **Tomar Decisiones Informadas:**
#   - Al tener un intervalo de confianza, los investigadores y analistas pueden tomar decisiones informadas sobre la precisión de sus estimaciones y la confianza que pueden tener en la generalización de los resultados a la población completa.
#
# **Ejemplo Ilustrativo:**
# - Supongamos que se estima la media de altura de una población con un intervalo de confianza del 95%. Si se repitiera el proceso de estimación muchas veces, se espera que el 95% de esos intervalos contengan la verdadera media de altura poblacional.
#
# **Conclusión:**
# - En resumen, los intervalos de confianza proporcionan un marco estadístico para expresar la incertidumbre asociada con las estimaciones de muestra. Son una herramienta crucial para tomar decisiones basadas en datos y comunicar la confianza en los resultados de la investigación o análisis estadístico.

# %% [markdown]
# ### Ejemplo de Intervalos de Confianza: Puntuaciones de Exámenes
#
# Supongamos que estamos interesados en estimar el puntaje promedio en matemáticas para una población de estudiantes de una escuela secundaria. Tomamos una muestra aleatoria de 100 estudiantes y calculamos la media de sus puntajes en matemáticas junto con un intervalo de confianza del 95%.
#
# 1. Recopilación de Datos de Muestra:
#    - Tomamos una muestra aleatoria de 100 estudiantes de la población de la escuela secundaria.
#    - Calculamos la media muestral de los puntajes en matemáticas: 75 puntos.
#    - Desviación estándar muestral (estimación de la población): 10 puntos.
#
# 2. Estimación de Intervalo de Confianza:
#    - Utilizamos la fórmula del intervalo de confianza para la media:
#      $$\text{Intervalo de Confianza} = \bar{x} \pm Z \left( \frac{s}{\sqrt{n}} \right)$$
#      donde $\bar{x}$ es la media muestral, $s$ es la desviación estándar muestral, $n$ es el tamaño de la muestra y $Z$ es el valor crítico asociado al nivel de confianza deseado (para el 95%, $Z \approx 1.96$).
#
#    - Sustituimos los valores conocidos:
#      $$\text{Intervalo de Confianza} = 75 \pm 1.96 \left( \frac{10}{\sqrt{100}} \right)$$
#
# 3. Resultado del Intervalo de Confianza:
#    - Calculamos el intervalo de confianza y obtenemos, por ejemplo, $75 \pm 2$, lo que significa que estamos bastante seguros de que el puntaje promedio en matemáticas para la población completa está en el rango de 73 a 77 puntos.
#
# 4. Interpretación:
#    - Con un nivel de confianza del 95%, podemos decir que si tomamos muchas muestras y calculamos intervalos de confianza similares, al menos el 95% de esos intervalos contendrían el verdadero puntaje promedio de matemáticas para toda la población.
#
# 5. Visualización Gráfica (Opcional):
#    - Podemos visualizar el intervalo de confianza en un gráfico para comunicar de manera efectiva la incertidumbre asociada con nuestra estimación.
#
# En este ejemplo, los intervalos de confianza nos proporcionan una medida de la incertidumbre en nuestra estimación del puntaje promedio en matemáticas. Son una herramienta esencial para comunicar la variabilidad esperada en nuestras conclusiones basadas en muestras y para tomar decisiones informadas sobre la población completa.

# %% [markdown]
# ### Ejemplo: Cálculo Intervalo de Confianza

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Datos de muestra
media_muestral = 75
desviacion_estandar_muestral = 10
tamanio_muestra = 100
nivel_confianza = 0.95

# Cálculo del intervalo de confianza
error_estandar = desviacion_estandar_muestral / np.sqrt(tamanio_muestra)
intervalo_confianza = stats.norm.interval(nivel_confianza, loc=media_muestral, scale=error_estandar)

# Visualización gráfica
plt.figure(figsize=(6, 6))
plt.errorbar(media_muestral, 0, xerr=error_estandar, fmt='o', color='red', label='Media Muestral')
plt.axvline(x=intervalo_confianza[0], color='blue', linestyle='dashed', linewidth=2, label='Límite Inferior')
plt.axvline(x=intervalo_confianza[1], color='blue', linestyle='dashed', linewidth=2, label='Límite Superior')
plt.title('Intervalo de Confianza para Puntajes de Exámenes en Matemáticas')
plt.xlabel('Puntaje Promedio en Matemáticas')
plt.legend()
plt.show()

print(f"Intervalo de Confianza ({nivel_confianza*100}%): {intervalo_confianza}")
# Out:
# Intervalo de Confianza (95.0%): (73.04003601545995, 76.95996398454005)

# %% [markdown]
# Este código utiliza la distribución normal para calcular el intervalo de confianza y visualiza la media muestral junto con los límites superior e inferior del intervalo en un gráfico de error. Observarás que el intervalo de confianza proporciona una estimación del rango en el cual se espera que esté el verdadero puntaje promedio en matemáticas para toda la población.
#
# La interpretación es que, con un nivel de confianza del 95%, podemos afirmar que es probable que el puntaje promedio de la población completa esté en el rango especificado por el intervalo de confianza. Este rango refleja la incertidumbre asociada con nuestra estimación basada en la muestra.

# %% [markdown]
# ### Términos clave para Intervalos de Confianza
#
# ##### Nivel de confianza
# * El porcentaje de intervalos de confianza, construidos de la misma manera a partir de la misma población, que se espera que contengan la estadística de interés.
#
# ##### Extremos del intervalo
# * El límite superior e inferior del intervalo de confianza.

# %% [markdown]
# Existe una aversión natural de los seres humanos hacia la incertidumbre; las personas (especialmente los expertos) dicen "no sé" con demasiada poca frecuencia. Los analistas y los gerentes, aunque reconocen la incertidumbre, a menudo depositan una fe indebida en una estimación cuando se presenta como un solo número (una estimación puntual). Presentar una estimación no como un solo número, sino como un rango, es una forma de contrarrestar esta tendencia. Los intervalos de confianza hacen esto de una manera fundamentada en los principios estadísticos de muestreo.
#
# Los intervalos de confianza siempre vienen con un nivel de cobertura, expresado como un porcentaje (alto), por ejemplo, 90% o 95%. Una forma de pensar en un intervalo de confianza del 90% es la siguiente: es el intervalo que encierra el 90% central de la distribución de muestreo del bootstrap de una estadística de muestra (ver "El Bootstrap" en la página 61). Más generalmente, un intervalo de confianza del $x$% alrededor de una estimación de muestra debería, en promedio, contener estimaciones de muestra similares al $x$% del tiempo (cuando se sigue un procedimiento de muestreo similar).
#
# Dada una muestra de tamaño $n$ y una estadística de muestra de interés, el algoritmo para un intervalo de confianza del bootstrap es el siguiente:
#
# 1. Selecciona aleatoriamente una muestra de tamaño n con reemplazo de los datos (un remuestreo).
# 2. Registra la estadística de interés para el remuestreo.
# 3. Repite los pasos 1-2 muchas $(R)$ veces.
# 4. Para un intervalo de confianza del $x$%, elimina $[(100-x) / 2]%$ de los resultados del remuestreo R desde ambos extremos de la distribución.
# 5. Los puntos de recorte son los extremos de un intervalo de confianza del bootstrap del $x$%.
#
# La Figura 2-9 muestra un intervalo de confianza del 90% para el ingreso anual promedio de los solicitantes de préstamos, basado en una muestra de 20 para la cual la media fue de $62,231.

# %%
# Imprimir la media de la Serie "loans_income".
print(loans_income.mean())

# Establecer una semilla para la generación de números aleatorios con NumPy para reproducibilidad.
np.random.seed(seed=3)

# Crear una muestra de 20 datos de ingresos de préstamos sin reemplazo.
sample20 = resample(loans_income, n_samples=20, replace=False)

# Imprimir la media de la muestra de 20 datos de ingresos de préstamos.
print(sample20.mean())

# Inicializar una lista llamada "results" para almacenar las medias de las muestras bootstrap.
results = []

# Realizar el procedimiento de bootstrap 500 veces en la muestra de 20 datos.
for nrepeat in range(500):
    # Resample (muestrear con reemplazo) la muestra de 20 datos.
    sample = resample(sample20)
    
    # Calcular la media de la muestra bootstrap y agregarla a la lista "results".
    results.append(sample.mean())

# Convertir la lista "results" en una Serie de pandas.
results = pd.Series(results)

# Calcular un intervalo de confianza del 90% a partir de las estadísticas bootstrap.
confidence_interval = list(results.quantile([0.05, 0.95]))

# Crear un histograma de las medias de las muestras bootstrap.
ax = results.plot.hist(bins=30, figsize=(6, 6))

# Dibujar líneas y etiquetas para el intervalo de confianza del 90%.
ax.plot(confidence_interval, [55, 55], color='black')
for x in confidence_interval:
    ax.plot([x, x], [0, 65], color='black')
    ax.text(x, 70, f'{x:.0f}', 
            horizontalalignment='center', verticalalignment='center')

# Etiquetar el intervalo de confianza del 90%.
ax.text(sum(confidence_interval) / 2, 60, '90% interval',
        horizontalalignment='center', verticalalignment='center')

# Calcular la media de las medias de las muestras bootstrap.
meanIncome = results.mean()

# Dibujar una línea punteada y etiquetar la media de las medias de las muestras bootstrap.
ax.plot([meanIncome, meanIncome], [0, 50], color='black', linestyle='--')
ax.text(meanIncome, 10, f'Mean: {meanIncome:.0f}',
        bbox=dict(facecolor='white', edgecolor='white', alpha=0.5),
        horizontalalignment='center', verticalalignment='center')

# Establecer límites en el eje y del histograma.
ax.set_ylim(0, 80)

# Etiquetar el eje y del histograma como 'Counts'.
ax.set_ylabel('Counts')

# Ajustar los márgenes para una presentación más compacta.
plt.tight_layout()

# Mostrar la figura.
plt.show()
# Out:
# 68760.51844
# 55734.1

# %% [markdown]
# **Figura 2-9**. Intervalo de confianza del bootstrap para el ingreso anual de solicitantes de préstamos, basado en una muestra de 20.

# %%
# Establecer una semilla para la generación de números aleatorios con NumPy para reproducibilidad.
np.random.seed(seed=3)

# Crear una muestra de 20 datos de ingresos de préstamos sin reemplazo.
sample20 = resample(loans_income, n_samples=20, replace=False)

# Inicializar una lista llamada "results" para almacenar las medias de las muestras bootstrap.
results = []

# Realizar el procedimiento de bootstrap 500 veces en la muestra de 20 datos.
for nrepeat in range(500):
    # Resample (muestrear con reemplazo) la muestra de 20 datos.
    sample = resample(sample20)
    
    # Calcular la media de la muestra bootstrap y agregarla a la lista "results".
    results.append(sample.mean())

# Convertir la lista "results" en una Serie de pandas.
results = pd.Series(results)

# Calcular el intervalo de confianza del 90% a partir de las estadísticas bootstrap.
confidence_interval_90 = list(results.quantile([0.05, 0.95]))

# Crear un histograma de las medias de las muestras bootstrap con un color específico.
ax = results.plot.hist(bins=30, figsize=(4, 3), color='C1')

# Dibujar líneas y etiquetas para el intervalo de confianza del 90%.
ax.plot(confidence_interval_90, [55, 55], color='black', linestyle='--')
for x in confidence_interval_90:
    ax.plot([x, x], [0, 60], color='black')
ax.text(82000, 50, 
        f'90% CI\n[{confidence_interval_90[0]:.0f}, {confidence_interval_90[1]:.0f}]',
       fontsize='small')

# Calcular el intervalo de confianza del 95% a partir de las estadísticas bootstrap.
confidence_interval_95 = list(results.quantile([0.025, 0.975]))

# Crear otro histograma de las medias de las muestras bootstrap.
ax = results.plot.hist(bins=30, figsize=(4, 3))

# Dibujar líneas y etiquetas para el intervalo de confianza del 95%.
ax.plot(confidence_interval_95, [65, 65], color='black', linestyle='--')
for x in confidence_interval_95:
    ax.plot([x, x], [0, 70], color='black')
ax.text(82000, 65, 
        f'95% CI\n[{confidence_interval_95[0]:.0f}, {confidence_interval_95[1]:.0f}]',
       fontsize='small')

# Calcular la media de las medias de las muestras bootstrap.
meanIncome = results.mean()

# Dibujar una línea punteada y etiquetar la media de las medias de las muestras bootstrap.
ax.plot([meanIncome, meanIncome], [0, 50], color='black', linestyle='--')
ax.text(meanIncome, 5, f'Mean: {meanIncome:.0f}',
        bbox=dict(facecolor='white', edgecolor='white', alpha=0.5),
        horizontalalignment='center', verticalalignment='center')

# Establecer límites en el eje y del histograma.
ax.set_ylim(0, 80)

# Establecer límites en el eje x del histograma.
ax.set_xlim(37000, 102000)

# Establecer marcas en el eje x del histograma.
ax.set_xticks([40000, 50000, 60000, 70000, 80000])

# Etiquetar el eje y del histograma como 'Counts'.
ax.set_ylabel('Counts')

# Mostrar la figura.
plt.show()

# %% [markdown]
# El bootstrap es una herramienta general que se puede utilizar para generar intervalos de confianza para la mayoría de las estadísticas o parámetros de modelos. Los libros de estadística y el software, con raíces en más de medio siglo de análisis estadístico sin computadoras, también harán referencia a intervalos de confianza generados por fórmulas, especialmente la distribución t de Student (ver "Distribución t de Student" en la página 75).

# %% [markdown]
# **Nota:**
#
# Por supuesto, lo que realmente nos interesa cuando tenemos un resultado de muestra es: "¿Cuál es la probabilidad de que el valor real se encuentre dentro de un cierto intervalo?" Esto no es realmente la pregunta que responde un intervalo de confianza, pero termina siendo cómo la mayoría de las personas interpretan la respuesta.
#
# La pregunta de probabilidad asociada con un intervalo de confianza comienza con la frase "Dado un procedimiento de muestreo y una población, ¿cuál es la probabilidad de que...?" Para ir en la dirección opuesta, "Dado un resultado de muestra, ¿cuál es la probabilidad de que (algo sea cierto sobre la población)?" implica cálculos más complejos y aspectos más profundos e incalculables.

# %% [markdown]
# *El porcentaje asociado con el intervalo de confianza se denomina* $Nivel\ de\ confianza$. Cuanto mayor sea el nivel de confianza, más amplio será el intervalo. Además, cuanto menor sea la muestra, más amplio será el intervalo (es decir, mayor será la incertidumbre). Ambos tienen sentido: cuanto más seguro quieras estar y menos datos tengas, más amplio debes hacer el intervalo de confianza para asegurarte suficientemente de capturar el valor real.

# %% [markdown]
# **Nota**:
#
# Para un científico de datos, un intervalo de confianza es una herramienta que se puede utilizar para tener una idea de cuán variable podría ser un resultado de muestra. Los científicos de datos usarían esta información no para publicar un artículo académico o presentar un resultado a una agencia reguladora (como podría hacer un investigador), sino más probablemente para comunicar el error potencial en una estimación y, tal vez, para determinar si se necesita una muestra más grande.

# %% [markdown]
# ### Ideas Clave
# * Los intervalos de confianza son la forma típica de presentar estimaciones como un rango de intervalo.
# * Cuantos más datos tengas, menos variable será una estimación de muestra.
# * Cuanto menor sea el nivel de confianza que puedas tolerar, más estrecho será el intervalo de confianza.
# * El bootstrap es una forma efectiva de construir intervalos de confianza.

# %% [markdown]
# ### Lecturas Adicionales
# * Para un enfoque de bootstrap sobre intervalos de confianza, consulta "Introductory Statistics and Analytics: A Resampling Perspective" de Peter Bruce (Wiley, 2014) o "Statistics: Unlocking the Power of Data, 2nd ed." de Robin Lock y otros cuatro miembros de la familia Lock (Wiley, 2016).
# * Los ingenieros, que necesitan comprender la precisión de sus mediciones, utilizan intervalos de confianza quizás más que la mayoría de las disciplinas. "Modern Engineering Statistics" de Thomas Ryan (Wiley, 2007) aborda los intervalos de confianza. También revisa una herramienta igualmente útil y que recibe menos atención: los intervalos de predicción (intervalos alrededor de un solo valor, en lugar de una media u otra estadística resumida).

# %% [markdown]
# # Distribución Normal
# La icónica distribución normal con forma de campana es fundamental en la estadística tradicional.1 El hecho de que las distribuciones de estadísticas de muestra a menudo tengan forma normal ha convertido a esta distribución en una herramienta poderosa en el desarrollo de fórmulas matemáticas que aproximan esas distribuciones.

# %% [markdown]
# ### Ejemplo de Distribución Normal: Alturas de Adultos
#
# Supongamos que estamos estudiando la altura de adultos en una población específica y que sabemos que la altura sigue una distribución normal con una media de 170 cm y una desviación estándar de 10 cm.
#
# 1. Parámetros de la Distribución Normal:
#    - Media (μ): 170 cm
#    - Desviación Estándar (σ): 10 cm
#
# 2. Propiedades de la Distribución Normal:
#    - La distribución es simétrica y tiene forma de campana.
#    - El 68% de los datos se encuentran dentro de una desviación estándar de la media.
#    - El 95% de los datos se encuentran dentro de dos desviaciones estándar de la media.
#    - El 99.7% de los datos se encuentran dentro de tres desviaciones estándar de la media.
#
# 3. Probabilidades y Preguntas:
#    - Pregunta 1: ¿Cuál es la probabilidad de que un adulto seleccionado al azar tenga una altura entre 160 cm y 180 cm?
#      - Respuesta 1: Podemos utilizar la regla empírica y decir que el 68% de las alturas están dentro de una desviación estándar. Por lo tanto, la probabilidad es alta, alrededor del 68%.
#
#    - Pregunta 2: ¿Cuál es la probabilidad de que un adulto tenga una altura superior a 190 cm?
#      - Respuesta 2: Podemos calcular la probabilidad utilizando la tabla de la distribución normal estándar o la función de densidad de probabilidad. Supongamos que es el 2.5% (por encima de dos desviaciones estándar), pero esto puede variar según la precisión requerida.
#
#    - Pregunta 3: ¿Cuál es la altura por encima de la cual se encuentra el 10% más bajo de la población?
#      - Respuesta 3: Utilizando la tabla de la distribución normal inversa, podemos encontrar el valor correspondiente al percentil 10, que nos dará la altura por encima de la cual el 10% de la población está.
#
# 4. Visualización Gráfica:
#    - Podemos crear un histograma de alturas en la población y superponer la curva de la distribución normal para visualizar cómo se ajusta la distribución a los datos reales.
#
# En este ejemplo, la distribución normal proporciona una herramienta poderosa para comprender y hacer inferencias sobre la altura de los adultos en la población. La familiaridad con las propiedades de la distribución normal facilita la interpretación de los resultados y la toma de decisiones basada en estas estimaciones estadísticas.

# %% [markdown]
# ### Ejemplo: Distribución Normal

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal
media = 0
desviacion_estandar = 1

# Generar datos desde una distribución normal
datos_normal = np.random.normal(media, desviacion_estandar, 10000)

# Crear histograma
plt.figure(figsize=(6, 6))
plt.hist(datos_normal, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)

# Crear curva de densidad de probabilidad (PDF) de la distribución normal
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = norm.pdf(x, media, desviacion_estandar)
plt.plot(x, pdf, 'k-', linewidth=2)

# Etiquetas y título
plt.title('Distribución Normal (Campana de Gauss)')
plt.xlabel('Valor')
plt.ylabel('Densidad de Probabilidad')
plt.show()

# %% [markdown]
# En este código, generamos 10,000 datos aleatorios desde una distribución normal con media 0 y desviación estándar 1. Luego, creamos un histograma para visualizar la distribución de los datos y superponemos una curva de densidad de probabilidad (PDF) de la distribución normal.
#
# La curva de Gauss (o campana de Gauss) es simétrica alrededor de la media y tiene la forma característica de una campana. Es comúnmente utilizada en estadísticas debido a propiedades como el Teorema del Límite Central, que establece que la suma o promedio de un gran número de variables independientes e idénticamente distribuidas tiende a seguir una distribución normal, independientemente de la forma de la distribución original.
#
# Este ejemplo ilustra visualmente cómo se ve la distribución normal y cómo la campana de Gauss es una representación gráfica de esta distribución.

# %% [markdown]
# ### Términos Clave para la Distribución Normal
#
# ##### Error
# * La diferencia entre un punto de datos y un valor predicho o promedio.
#
# ##### Estandarizar
# * Restar la media y dividir por la desviación estándar.
#
# ##### $Z-score$
# * El resultado de estandarizar un punto de datos individual.
#
# ##### Normal estándar
# * Una distribución normal con media = 0 y desviación estándar = 1.
#
# ##### $QQ-Plot$
# * Un gráfico para visualizar qué tan cerca está una distribución de muestra de una distribución especificada, por ejemplo, la distribución normal.

# %% [markdown]
# En una distribución normal (Figura 2-10), el 68% de los datos se encuentra dentro de una desviación estándar de la media, y el 95% se encuentra dentro de dos desviaciones estándar.

# %% [markdown]
# **Nota**:
#
# Es un error común pensar que la distribución normal se llama así porque la mayoría de los datos sigue una distribución normal, es decir, es lo normal. La mayoría de las variables utilizadas en un proyecto típico de ciencia de datos, de hecho, la mayoría de los datos en su conjunto, no siguen una distribución normal: consulta "Distribuciones de Cola Larga" en la página 73. La utilidad de la distribución normal se deriva del hecho de que muchas estadísticas siguen una distribución normal en su distribución de muestreo. Aun así, las suposiciones de normalidad suelen ser un último recurso, utilizado cuando no se disponen de distribuciones de probabilidad empíricas o distribuciones de bootstrap.

# %% [markdown]
# **Nota:**
#
# La curva de campana es icónica pero quizás sobrevalorada. George W. Cobb, el estadístico de Mount Holyoke conocido por su contribución a la filosofía de la enseñanza de estadísticas introductorias, argumentó en un editorial de noviembre de 2015 en el American Statistician que "el curso introductorio estándar, que coloca a la distribución normal en su centro, había superado la utilidad de su centralidad".

# %% [markdown]
# ![Captura de pantalla 2024-01-21 154958.png](attachment:fdf2e43e-1c68-41a5-95c5-9e6182ecfad0.png)

# %% [markdown]
# **Figura 2-10**. Curva normal

# %% [markdown]
# **Nota:**
#
# La distribución normal también se conoce como distribución $gaussiana$ en honor a Carl Friedrich Gauss, un prodigioso matemático alemán de finales del siglo XVIII y principios del XIX. Otro nombre que se usaba anteriormente para la distribución normal era la "distribución de errores". Estadísticamente hablando, un $error$ es la diferencia entre un valor real y una estimación estadística como la media de la muestra. Por ejemplo, la desviación estándar (ver "Estimaciones de Variabilidad" en la página 13) se basa en los errores con respecto a la media de los datos. El desarrollo de Gauss de la distribución normal surgió de su estudio de los errores de las mediciones astronómicas que se encontraron distribuidos de manera normal.

# %% [markdown]
# # Distribución Normal Estándar y Gráficos QQ
#
# Una $Distribución\ normal\ estándar$ es aquella en la que las unidades en el eje x se expresan en términos de desviaciones estándar respecto a la media. Para comparar datos con una distribución normal estándar, restas la media y luego divides por la desviación estándar; esto también se llama $Normalización$ o $Estandarización$ (ver "Estandarización (Normalización, z-Scores)" en la página 243). Ten en cuenta que la "estandarización" en este sentido no está relacionada con la estandarización de registros de base de datos (conversión a un formato común). El valor transformado se denomina $z-score$, y a veces se llama a la distribución normal como la $z-distribución$.
#
# Un $gráfico$ $QQ$ (Quantile-Quantile) se utiliza para determinar visualmente qué tan cerca está una muestra de una distribución especificada, en este caso, la distribución normal. El gráfico QQ ordena los z-scores de menor a mayor y grafica el z-score de cada valor en el eje y; el eje x es el cuantil correspondiente de una distribución normal para el rango de ese valor. Dado que los datos están normalizados, las unidades corresponden al número de desviaciones estándar respecto a la media. Si los puntos caen aproximadamente en la línea diagonal, entonces se puede considerar que la distribución de la muestra está cerca de ser normal. La Figura 2-11 muestra un gráfico QQ para una muestra de 100 valores generados aleatoriamente a partir de una distribución normal; como era de esperar, los puntos siguen de cerca la línea. Esta figura se puede producir en R con la función qqnorm:

# %% [markdown]
#     norm_samp <- rnorm(100)
#     qqnorm(norm_samp)
#     abline(a=0, b=1, col='grey'))

# %% [markdown]
# En Python, utiliza el método `scipy.stats.probplot` para crear el gráfico QQ-Plot.

# %%
# Crear una figura y un eje (subgráfico) utilizando Matplotlib con un tamaño de 4x4 pulgadas.
fig, ax = plt.subplots(figsize=(4, 4))

# Generar una muestra de 100 valores aleatorios de una distribución normal estándar.
norm_sample = stats.norm.rvs(size=100)

# Crear un gráfico de probabilidad (probability plot) utilizando la muestra generada y el eje especificado.
stats.probplot(norm_sample, plot=ax)
# Out:
# ((array([-2.46203784, -2.12570747, -1.93122778, -1.79044653, -1.67819304,
#          -1.58381122, -1.50174123, -1.42869743, -1.36256869, -1.30191411,
#          -1.24570419, -1.19317644, -1.14374949, -1.09696931, -1.05247413,
#          -1.00997067, -0.96921765, -0.93001393, -0.89218993, -0.85560121,
#          -0.82012357, -0.78564937, -0.75208458, -0.71934648, -0.68736185,
#          -0.65606548, -0.62539893, -0.59530962, -0.56574992, -0.53667655,
#          -0.50804994, -0.47983378, -0.45199463, -0.42450149, -0.39732558,
#          -0.37044003, -0.34381966, -0.31744076, -0.29128096, -0.26531902,
#          -0.23953472, -0.21390872, -0.18842244, -0.16305799, -0.13779803,
#          -0.1126257 , -0.08752455, -0.06247843, -0.03747145, -0.01248789,
#           0.01248789,  0.03747145,  0.06247843,  0.08752455,  0.1126257 ,
#           0.13779803,  0.16305799,  0.18842244,  0.21390872,  0.23953472,
#           0.26531902,  0.29128096,  0.31744076,  0.34381966,  0.37044003,
# ...

# %% [markdown]
# **Figura 2-11**. Gráfico QQ de una muestra de 100 valores extraídos de una distribución normal estándar

# %% [markdown]
# ### Ejemplo de Distribución Normal Estándar y Gráfico QQ en Python:

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Generar una muestra de 100 valores de una distribución normal
np.random.seed(123)  # Para reproducibilidad
sample_data = np.random.normal(size=100)

# Calcular z-scores (estandarizar la muestra)
z_scores = (sample_data - np.mean(sample_data)) / np.std(sample_data)

# Crear un gráfico QQ
stats.probplot(z_scores, dist="norm", plot=plt)

# Mostrar el gráfico
plt.title("Gráfico QQ para Distribución Normal Estándar")
plt.show()

# %% [markdown]
# **Explicación:**
# 1. **Generación de la Muestra:**
#    - Se genera una muestra de 100 valores aleatorios a partir de una distribución normal utilizando `numpy.random.normal`.
#
# 2. **Estandarización (Cálculo de Z-scores):**
#    - Se calculan los z-scores (desviaciones estándar respecto a la media) para cada valor en la muestra.
#
# 3. **Creación del Gráfico QQ:**
#    - Se utiliza `scipy.stats.probplot` para crear el gráfico QQ.
#    - El argumento `dist="norm"` especifica que estamos comparando con una distribución normal estándar.
#
# 4. **Visualización del Gráfico:**
#    - Se muestra el gráfico QQ que permite visualizar la proximidad de la muestra a la distribución normal estándar.
#
# Este ejemplo en Python ilustra cómo generar una muestra normalizada (z-scores) y crear un gráfico QQ para evaluar visualmente la normalidad de la muestra en comparación con una distribución normal estándar. Si los puntos en el gráfico siguen la línea diagonal, indica una buena aproximación a la normalidad.

# %% [markdown]
# **Nota:**
#
# La conversión de datos a $z-scores$ (es decir, estandarizar o normalizar los datos) no hace que los datos sigan una distribución normal. Simplemente coloca los datos en la misma escala que la distribución normal estándar, a menudo con fines de comparación.

# %% [markdown]
# ### Ideas Clave
# * La distribución normal fue esencial para el desarrollo histórico de la estadística, ya que permitió la aproximación matemática de la incertidumbre y la variabilidad.
# * Aunque los datos sin procesar no suelen seguir una distribución normal, los errores a menudo sí lo hacen, al igual que los promedios y totales en muestras grandes.
# * Para convertir datos a z-scores, restas la media de los datos y divides por la desviación estándar; luego puedes comparar los datos con una distribución normal.

# %% [markdown]
# # Distribuciones de Cola Larga
# A pesar de la importancia histórica de la distribución normal en estadísticas y en contraste con lo que sugiere el nombre, los datos generalmente no siguen una distribución normal.

# %% [markdown]
# ### Ejemplo de Distribuciones de Cola Larga:
#
# En estadísticas y ciencia de datos, a menudo encontramos distribuciones que exhiben colas largas o "heavy tails". Un ejemplo clásico de esto es la distribución de Pareto, que modela fenómenos donde la mayoría de los eventos son raros, pero los eventos extremadamente raros pueden tener un impacto significativo. Veamos cómo podríamos generar y visualizar una distribución de Pareto:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pareto

# Parámetros de la distribución de Pareto
shape = 3.0  # Parámetro de forma (alpha)
scale = 1.0  # Parámetro de escala (xm)

# Generar datos de una distribución de Pareto
data = pareto.rvs(shape, scale=scale, size=1000, random_state=123)

# Visualizar el histograma de los datos
plt.hist(data, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black')

# Trazar la función de densidad de probabilidad de Pareto
x = np.linspace(1, 10, 100)
pdf = pareto.pdf(x, shape, scale=scale)
plt.plot(x, pdf, 'r-', lw=2, label='Distribución de Pareto')

# Ajustar la apariencia del gráfico
plt.title('Distribución de Pareto (Cola Larga)')
plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Explicación:**
# 1. **Parámetros de la Distribución de Pareto:**
#    - `shape`: Parámetro de forma (alpha) que determina la inclinación de la cola larga.
#    - `scale`: Parámetro de escala (xm) que establece el valor mínimo de la distribución.
#
# 2. **Generación de Datos de Pareto:**
#    - Se generan 1000 datos de una distribución de Pareto utilizando `scipy.stats.pareto.rvs`.
#
# 3. **Visualización del Histograma y PDF de Pareto:**
#    - Se visualiza el histograma de los datos y se superpone la función de densidad de probabilidad (PDF) de la distribución de Pareto.
#
# 4. **Ajuste del Gráfico:**
#    - Se ajustan etiquetas y título del gráfico para una mejor comprensión.
#
# Este ejemplo ilustra cómo generar y visualizar una distribución de Pareto, que es un ejemplo común de una distribución con colas largas. En este tipo de distribuciones, los eventos extremos son más probables de lo que sugeriría una distribución normal.

# %% [markdown]
# ### Términos Clave para Distribuciones de Cola Larga
#
# ##### Cola
# * La porción larga y estrecha de una distribución de frecuencia, donde ocurren valores relativamente extremos con baja frecuencia.
#
# ##### Asimetría
# * Cuando una cola de una distribución es más larga que la otra.

# %% [markdown]
# Si bien la distribución normal a menudo es apropiada y útil en lo que respecta a la distribución de errores y estadísticas de muestra, generalmente no caracteriza la distribución de datos sin procesar. A veces, la distribución es altamente sesgada (asimétrica), como en el caso de los datos de ingresos; o la distribución puede ser discreta, como en el caso de datos binomiales. Tanto las distribuciones simétricas como asimétricas pueden tener colas largas. Las colas de una distribución corresponden a los valores extremos (pequeños y grandes). Las colas largas, y la protección contra ellas, son ampliamente reconocidas en el trabajo práctico. Nassim Taleb ha propuesto la teoría del cisne negro, que predice que eventos anómalos, como un colapso del mercado de valores, son mucho más probables de lo que se predice mediante la distribución normal.
# Un buen ejemplo para ilustrar la naturaleza de colas largas de los datos son los rendimientos bursátiles. La Figura 2-12 muestra el gráfico QQ para los rendimientos bursátiles diarios de Netflix (NFLX). Esto se genera en R mediante:

# %% [markdown]
#     nflx <- sp500_px[,'NFLX']
#         nflx <- diff(log(nflx[nflx>0]))
#         qqnorm(nflx)
#         abline(a=0, b=1, col='grey')

# %% [markdown]
# El código Python correspondiente es:

# %%
# Leer datos del índice S&P 500 desde un archivo CSV (SP500_DATA_CSV) usando pandas.
sp500_px = pd.read_csv(SP500_DATA_CSV)

# Seleccionar la columna correspondiente a los precios de las acciones de Netflix (NFLX).
nflx = sp500_px.NFLX

# Calcular los rendimientos logarítmicos diarios de Netflix y eliminar los valores no positivos.
nflx = np.diff(np.log(nflx[nflx > 0]))

# Crear una figura y un eje (subgráfico) utilizando Matplotlib con un tamaño de 4x4 pulgadas.
fig, ax = plt.subplots(figsize=(4, 4))

# Crear un gráfico de probabilidad (probability plot) utilizando los rendimientos logarítmicos diarios de Netflix y el eje especificado.
stats.probplot(nflx, plot=ax)

# Ajustar los márgenes para una presentación más compacta.
plt.tight_layout()

# Mostrar la igura.
plt.show()

# %%
# Seleccionar la columna correspondiente a los precios de las acciones de Netflix (NFLX) desde el DataFrame sp500_px.
nflx = sp500_px.NFLX

# Calcular los rendimientos logarítmicos diarios de Netflix y eliminar los valores no positivos.
nflx = np.diff(np.log(nflx[nflx > 0]))

# Crear una figura y un eje (subgráfico) utilizando Matplotlib con un tamaño de 4x4 pulgadas.
fig, ax = plt.subplots(figsize=(4, 4))

# Crear un gráfico de probabilidad (probability plot) utilizando los rendimientos logarítmicos diarios de Netflix y el eje especificado.
stats.probplot(nflx, plot=ax)
# Out:
# ((array([-3.33278964, -3.07756454, -2.93575124, ...,  2.93575124,
#           3.07756454,  3.33278964]),
#   array([-6.60529819, -6.09667121, -5.40220961, ...,  5.12547859,
#           5.87072271,  6.03787   ])),
#  (1.4823778663727092, 0.0015561067366313861, 0.9941828221936322))

# %% [markdown]
# **Figura 2-12**. Gráfico QQ de los rendimientos para Netflix (NFLX)

# %% [markdown]
# En contraste con la Figura 2-11, los puntos están bastante por debajo de la línea para valores bajos y bastante por encima de la línea para valores altos, lo que indica que los datos no siguen una distribución normal. Esto significa que es mucho más probable observar valores extremos de lo que se esperaría si los datos tuvieran una distribución normal. La Figura 2-12 muestra otro fenómeno común: los puntos están cerca de la línea para los datos dentro de una desviación estándar de la media. Tukey se refiere a este fenómeno como datos "normales en el medio" pero con colas mucho más largas (ver [Tukey-1987]).

# %% [markdown]
# **Nota:**
#
# Existe mucha literatura estadística sobre la tarea de ajustar distribuciones estadísticas a datos observados. Ten cuidado con un enfoque excesivamente centrado en los datos para este trabajo, que es tanto arte como ciencia. Los datos son variables y a menudo, a simple vista, son consistentes con más de una forma y tipo de distribución. Por lo general, es necesario aplicar conocimientos de dominio y estadísticos para determinar qué tipo de distribución es apropiado para modelar una situación dada. Por ejemplo, podríamos tener datos sobre el nivel de tráfico en Internet en un servidor durante muchos períodos consecutivos de cinco segundos. Es útil saber que la mejor distribución para modelar "eventos por período de tiempo" es la de Poisson (ver "Distribuciones de Poisson" en la página 83).

# %% [markdown]
# ### Ideas Clave
# * La mayoría de los datos no sigue una distribución normal.
# * Suponer una distribución normal puede llevar a una subestimación de eventos extremos ("cisnes negros").

# %% [markdown]
# ### Lecturas Adicionales
# * "El Cisne Negro", 2da ed., de Nassim Nicholas Taleb (Random House, 2010)
# * "Handbook of Statistical Distributions with Applications", 2da ed., de K. Krishnamoorthy (Chapman & Hall/CRC Press, 2016)

# %% [markdown]
# # Distribución t de Student
# La $Distribución\ t$ es una distribución con forma normal, excepto que es un poco más gruesa y larga en las colas. Se utiliza ampliamente para representar distribuciones de estadísticas de muestra. Las distribuciones de medias de muestra suelen tener forma de distribución t, y existe una familia de distribuciones t que difieren según el tamaño de la muestra. A medida que aumenta el tamaño de la muestra, la distribución t se vuelve más parecida a una distribución normal.

# %% [markdown]
# ### Ejemplo de Distribución t de Student:
#
# La distribución t de Student se utiliza comúnmente en inferencia estadística cuando se trabaja con muestras pequeñas. Veamos cómo podríamos generar y visualizar una distribución t con diferentes grados de libertad:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Parámetros de la distribución t
degrees_of_freedom = [3, 10, 30]  # Diferentes grados de libertad

# Generar datos de una distribución t para diferentes grados de libertad
data = [t.rvs(df, size=1000, random_state=123) for df in degrees_of_freedom]

# Visualizar histogramas de las distribuciones t
plt.figure(figsize=(6, 6))

for i, df in enumerate(degrees_of_freedom):
    plt.hist(data[i], bins=30, density=True, alpha=0.7, label=f'df = {df}')

# Ajustar la apariencia del gráfico
plt.title('Distribución t de Student con Diferentes Grados de Libertad')
plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Explicación:**
# 1. **Parámetros de la Distribución t:**
#    - `degrees_of_freedom`: Lista de diferentes grados de libertad para la distribución t.
#
# 2. **Generación de Datos de la Distribución t:**
#    - Se generan 1000 datos para cada distribución t con diferentes grados de libertad.
#
# 3. **Visualización de Histogramas:**
#    - Se visualizan los histogramas de las distribuciones t para diferentes grados de libertad en el mismo gráfico.
#
# 4. **Ajuste del Gráfico:**
#    - Se ajustan etiquetas y título del gráfico para una mejor comprensión.
#
# Este ejemplo ilustra cómo generar y visualizar la distribución t de Student con diferentes grados de libertad. Como se menciona en la descripción, a medida que aumenta el tamaño de la muestra (grados de libertad), la distribución t se aproxima a una distribución normal estándar.

# %% [markdown]
# ### Términos Clave para la Distribución t de Student
#
# ##### $n$
# * Tamaño de la muestra.
#
# ##### Grados de libertad
# * Un parámetro que permite que la distribución t se ajuste a diferentes tamaños de muestra, estadísticas y números de grupos.

# %% [markdown]
# La distribución t se llama a menudo t de Student porque fue publicada en 1908 en Biometrika por W. S. Gosset bajo el nombre de "Student". El empleador de Gosset, la cervecería Guinness, no quería que los competidores supieran que estaba utilizando métodos estadísticos, por lo que insistió en que Gosset no usara su nombre en el artículo.
#
# Gosset quería responder a la pregunta "¿Cuál es la distribución muestral de la media de una muestra extraída de una población más grande?" Comenzó con un experimento de remuestreo, extrayendo muestras aleatorias de 4 de un conjunto de datos de 3,000 medidas de la altura y longitud del dedo medio izquierdo de criminales. (En esa época, la eugenesia generaba mucho interés en los datos sobre criminales y en descubrir correlaciones entre las tendencias criminales y atributos físicos o psicológicos). Gosset trazó los resultados estandarizados (los z-scores) en el eje x y la frecuencia en el eje y. Por separado, había derivado una función, ahora conocida como la t de Student, y ajustó esta función sobre los resultados de la muestra, trazando la comparación (ver Figura 2-13).

# %% [markdown]
# ![Captura de pantalla 2024-01-21 160759.png](attachment:39fe8281-3d10-4bcf-a225-78c038461968.png)

# %% [markdown]
# **Figura 2-13**. Resultados del experimento de remuestreo de Gosset y curva t ajustada (de su artículo de Biometrika de 1908)

# %% [markdown]
# Se pueden comparar varias estadísticas diferentes, después de estandarización, con la distribución t para estimar intervalos de confianza a la luz de la variación del muestreo. Considere una muestra de tamaño $n$ para la cual se ha calculado la media muestral $\bar{x}$. Si $s$ es la desviación estándar de la muestra, un intervalo de confianza del 90% alrededor de la media muestral se da por:
#
# $$ \bar{x} \pm t_{n-1 (0.05)} \cdot \frac{s}{\sqrt{n}} $$
#
# donde $ t_{n-1 (0.05)} $ es el valor del $estadístico\ t$, con $(n-1)$ grados de libertad (ver "Grados de Libertad" en la página 116), que "recorta" el 5% de la distribución t en ambos extremos. La distribución t se ha utilizado como referencia para la distribución de una media muestral, la diferencia entre dos medias muestrales, parámetros de regresión y otras estadísticas.
#
# Si la potencia informática hubiera estado ampliamente disponible en 1908, es probable que las estadísticas se hubieran basado mucho más en métodos de remuestreo intensivos computacionalmente desde el principio. Al carecer de computadoras, los estadísticos recurrieron a las matemáticas y a funciones como la distribución t para aproximar distribuciones de muestreo. La potencia informática permitió experimentos prácticos de remuestreo en la década de 1980, pero para entonces, el uso de la distribución t y distribuciones similares ya se había arraigado profundamente en libros de texto y software.
#
# La precisión de la distribución t al representar el comportamiento de una estadística de muestra requiere que la distribución de esa estadística para esa muestra tenga forma de una distribución normal. Resulta que las estadísticas de muestra a menudo siguen una distribución normal, incluso cuando los datos de la población subyacente no lo hacen (un hecho que llevó a la aplicación generalizada de la distribución t). Esto nos lleva de nuevo al fenómeno conocido como el teorema del límite central (ver "Teorema del Límite Central" en la página 60).

# %% [markdown]
# **Nota:**
#
# ¿Qué necesitan saber los científicos de datos sobre la distribución t y el teorema del límite central? No mucho. La distribución t se utiliza en la inferencia estadística clásica, pero no es tan fundamental para los propósitos de la ciencia de datos. Comprender y cuantificar la incertidumbre y la variación son importantes para los científicos de datos, pero el muestreo empírico bootstrap puede responder a la mayoría de las preguntas sobre el error de muestreo. Sin embargo, los científicos de datos encontrarán rutinariamente estadísticas t en la salida de software estadístico y procedimientos estadísticos en R, por ejemplo, en pruebas A/B y regresiones, por lo que es útil estar familiarizado con su propósito.

# %% [markdown]
# ### Ideas Clave
# * La distribución t es en realidad una familia de distribuciones que se asemejan a la distribución normal pero con colas más gruesas.
# * La distribución t se utiliza ampliamente como base de referencia para la distribución de medias muestrales, diferencias entre dos medias muestrales, parámetros de regresión y más.

# %% [markdown]
# ### Lecturas Adicionales
# * El artículo original de W.S. Gosset tal como se publicó en Biometrika en 1908 está disponible en PDF.
# * Un tratamiento estándar de la distribución t se puede encontrar en el recurso en línea de David Lane.

# %% [markdown]
# # Distribución Binomial
# Resultados de sí/no (binomiales) son fundamentales en la analítica, ya que a menudo son el resultado de una decisión u otro proceso; comprar/no comprar, hacer clic/no hacer clic, sobrevivir/morir, entre otros. Central para entender la distribución binomial es la idea de un conjunto de ensayos, cada ensayo con dos posibles resultados con probabilidades definidas.
# Por ejemplo, lanzar una moneda 10 veces es un experimento binomial con 10 ensayos, cada ensayo con dos posibles resultados (cara o cruz); ver Figura 2-14. Tales resultados de sí/no o de 0/1 se denominan resultados binarios, y no es necesario que tengan probabilidades de 50/50. Cualquier conjunto de probabilidades que sume 1.0 es posible. En estadísticas, es convencional llamar al resultado "1" el resultado de éxito; también es práctica común asignar "1" al resultado más raro. El uso del término éxito no implica que el resultado sea deseable o beneficioso, pero tiende a indicar el resultado de interés. Por ejemplo, los incumplimientos de préstamos o transacciones fraudulentas son eventos relativamente poco comunes que podríamos estar interesados en predecir, por lo que se denominan "1" o "éxitos".

# %% [markdown]
# ### Ejemplo de Distribución Binomial:
#
# Supongamos que estamos realizando un experimento donde lanzamos un dado justo (con seis caras numeradas del 1 al 6) 5 veces y queremos calcular la probabilidad de obtener exactamente 3 veces el número 4.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parámetros de la distribución binomial
num_trials = 5  # Número de ensayos (lanzamientos del dado)
probability_of_success = 1/6  # Probabilidad de obtener el número 4 en un lanzamiento

# Número de éxitos deseados
desired_successes = 3

# Calcular la probabilidad de obtener exactamente 3 veces el número 4
probability = binom.pmf(desired_successes, num_trials, probability_of_success)

# Visualizar la distribución binomial para el experimento
x = np.arange(0, num_trials + 1)
y = binom.pmf(x, num_trials, probability_of_success)

plt.stem(x, y, basefmt='b-', linefmt='r-', markerfmt='ro')
plt.title('Distribución Binomial para 5 lanzamientos del dado')
plt.xlabel('Número de Éxitos (Obtener el número 4)')
plt.ylabel('Probabilidad')
plt.show()

# Mostrar la probabilidad calculada
print(f'La probabilidad de obtener exactamente 3 veces el número 4 en 5 lanzamientos es: {probability:.4f}')
# Out:
# La probabilidad de obtener exactamente 3 veces el número 4 en 5 lanzamientos es: 0.0322

# %% [markdown]
# **Explicación:**
# 1. **Parámetros de la Distribución Binomial:**
#    - `num_trials`: Número de ensayos (lanzamientos del dado).
#    - `probability_of_success`: Probabilidad de obtener el número 4 en un lanzamiento del dado.
#
# 2. **Número de Éxitos Deseados:**
#    - `desired_successes`: Número de veces que queremos obtener el número 4.
#
# 3. **Cálculo de Probabilidad:**
#    - Se utiliza la función de masa de probabilidad (`pmf`) de la distribución binomial para calcular la probabilidad de obtener exactamente 3 veces el número 4 en 5 lanzamientos.
#
# 4. **Visualización de la Distribución Binomial:**
#    - Se visualiza la distribución binomial para el experimento de lanzar un dado justo 5 veces.
#
# Este ejemplo ilustra cómo calcular y visualizar la distribución binomial para un experimento de lanzar un dado justo 5 veces y calcular la probabilidad de obtener exactamente 3 veces el número 4.

# %% [markdown]
# ![Captura de pantalla 2024-01-21 161538.png](attachment:355f73e0-2e99-4fe1-82fe-f23c9963163c.png)

# %% [markdown]
# **Figura 2-14**. El reverso de una moneda buffalo nickel

# %% [markdown]
# ### Términos Clave para la Distribución Binomial
#
# ##### Prueba
# * Un evento con un resultado discreto (por ejemplo, lanzar una moneda).
#
# ##### Éxito
# * El resultado de interés para una prueba.
# * Sinónimo "1" (en contraposición a "0").
#
# ##### Binomial
# * Que tiene dos resultados.
# * Sinónimos sí/no, 0/1, binario.
#
# ##### Prueba Binomial
# * Una prueba con dos resultados.
# * Sinónimo Prueba de Bernoulli.
#
# ##### Distribución Binomial
# * Distribución del número de éxitos en x pruebas.
# * Sinónimo Distribución de Bernoulli.

# %% [markdown]
# La distribución binomial es la distribución de frecuencia del número de éxitos (x) en un número dado de pruebas (n) con una probabilidad especificada (p) de éxito en cada prueba. Existe una familia de distribuciones binomiales, dependiendo de los valores de n y p. La distribución binomial respondería a una pregunta como:
# Si la probabilidad de que un clic se convierta en una venta es 0.02, ¿cuál es la probabilidad de observar 0 ventas en 200 clics?
# La función `dbinom` en R calcula las probabilidades binomiales. Por ejemplo:

# %% [markdown]
#     dbinom(x=2, size=5, p=0.1)

# %% [markdown]
# devolvería 0.0729, la probabilidad de observar exactamente x = 2 éxitos en tamaño = 5 pruebas, donde la probabilidad de éxito para cada prueba es p = 0.1. Para nuestro ejemplo anterior, usamos x = 0, tamaño = 200 y p = 0.02. Con estos argumentos, `dbinom` devuelve una probabilidad de 0.0176.
# A menudo, estamos interesados en determinar la probabilidad de x o menos éxitos en n pruebas. En este caso, utilizamos la función `pbinom`:

# %% [markdown]
# pbinom(2, 5, 0.1)

# %% [markdown]
# Esto devolvería 0.9914, la probabilidad de observar dos o menos éxitos en cinco pruebas, donde la probabilidad de éxito para cada prueba es 0.1.
# El módulo `scipy.stats` implementa una amplia variedad de distribuciones estadísticas. Para la distribución binomial, utiliza las funciones `stats.binom.pmf` y `stats.binom.cdf`:

# %%
# Calcular y imprimir la probabilidad de obtener exactamente 2 éxitos en 5 ensayos,
# con una probabilidad de éxito del 10%, utilizando la función de masa de probabilidad (PMF)
# de la distribución binomial proporcionada por SciPy.

print(stats.binom.pmf(2, n=5, p=0.1))
# Out:
# 0.07289999999999992

# %%
# Calcular y imprimir la probabilidad acumulativa de obtener hasta 2 éxitos en 5 ensayos,
# con una probabilidad de éxito del 10%, utilizando la función de distribución acumulativa (CDF)
# de la distribución binomial proporcionada por SciPy.

print(stats.binom.cdf(2, n=5, p=0.1))
# Out:
# 0.99144

# %% [markdown]
# La media de una distribución binomial es $n$ $×$ $p$; también puedes pensar en esto como el número esperado de éxitos en n pruebas, con una probabilidad de éxito $=$ $p$.
#
# La varianza e$s$ $n$ $×$ $p$ $× (1 − $p). Con un número suficientemente grande de pruebas (especialmente cuando p se acerca a 0.50), la distribución binomial es virtualmente indistinguible de la distribución normal. De hecho, calcular probabilidades binomiales con tamaños de muestra grandes es computacionalmente exigente, y la mayoría de los procedimientos estadísticos utilizan la distribución normal, con la media y la varianza, como una aproximación.

# %% [markdown]
# ### Ideas Clave
# * Los resultados binomiales son importantes de modelar, ya que representan, entre otras cosas, decisiones fundamentales (comprar o no comprar, hacer clic o no hacer clic, sobrevivir o morir, etc.).
# * Una prueba binomial es un experimento con dos resultados posibles: uno con probabilidad p y el otro con probabilidad 1 - p.
# * Con un n grande y siempre que p no esté demasiado cerca de 0 o 1, la distribución binomial puede aproximarse a la distribución normal.

# %% [markdown]
# ### Lecturas Adicionales
# * Lee sobre el "quincunx", un dispositivo de simulación similar a un pinball que ilustra la distribución binomial.
# * La distribución binomial es fundamental en estadísticas introductorias, y todos los textos introductorios de estadísticas tendrán uno o dos capítulos al respecto.

# %% [markdown]
# # Distribución Chi-Cuadrado
# Una idea importante en estadísticas es la desviación de la expectativa, especialmente en lo que respecta a recuentos de categorías. La expectativa se define de manera laxa como "nada inusual o notable en los datos" (por ejemplo, ninguna correlación entre variables o patrones predecibles). Esto también se denomina la "hipótesis nula" o "modelo nulo" (consulte "La Hipótesis Nula" en la página 94).
#
# Por ejemplo, podrías querer probar si una variable (digamos, una variable de fila que representa el género) es independiente de otra (digamos, una variable de columna que representa "fue ascendido en el trabajo"), y tienes recuentos del número en cada una de las celdas de la tabla de datos. El estadístico que mide en qué medida los resultados se desvían de la expectativa nula de independencia es el estadístico chi-cuadrado. Es la diferencia entre los valores observados y esperados, dividida por la raíz cuadrada del valor esperado, elevada al cuadrado, y luego sumada en todas las categorías. Este proceso estandariza el estadístico para que pueda compararse con una distribución de referencia. Una forma más general de expresar esto es señalar que el estadístico chi-cuadrado es una medida de en qué medida un conjunto de valores observados "se ajusta" a una distribución especificada (una prueba de bondad de ajuste). Es útil para determinar si múltiples tratamientos (una prueba "A/B/C...") difieren entre sí en sus efectos.
#
# La distribución chi-cuadrado es la distribución de este estadístico bajo repeticiones de muestreos de extracciones del modelo nulo; consulte "Prueba de Chi-Cuadrado" en la página 124 para obtener un algoritmo detallado y la fórmula chi-cuadrado para una tabla de datos. Un valor bajo de chi-cuadrado para un conjunto de recuentos indica que siguen de cerca la distribución esperada. Un chi-cuadrado alto indica que difieren notablemente de lo que se espera. Hay una variedad de distribuciones chi-cuadrado asociadas con diferentes grados de libertad (por ejemplo, el número de observaciones; consulte "Grados de Libertad" en la página 116).

# %% [markdown]
# ### Ejemplo de Distribución Chi-Cuadrado:
#
# Supongamos que tienes una tabla de contingencia que representa el número de empleados promovidos en función de su género. Quieres probar si hay una asociación entre el género y las promociones utilizando la prueba de chi-cuadrado. Aquí está un ejemplo simple en Python:

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Crear una tabla de contingencia (ejemplo ficticio)
data = np.array([[50, 30], [20, 40]])  # Filas representan género (Hombre, Mujer), columnas representan promoción (Sí, No)

# Realizar la prueba de chi-cuadrado
chi2, p, _, _ = chi2_contingency(data)

# Mostrar resultados
print(f'Estadístico de Chi-Cuadrado: {chi2:.4f}')
print(f'Valor p: {p:.4f}')

# Interpretar los resultados
alpha = 0.05
if p < alpha:
    print("Hay evidencia suficiente para rechazar la hipótesis nula.")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula.")
# Out:
# Estadístico de Chi-Cuadrado: 10.5292
# Valor p: 0.0012
# Hay evidencia suficiente para rechazar la hipótesis nula.

# %% [markdown]
# Explicación:
# 1. Creación de la Tabla de Contingencia:
#    - `data`: Una matriz que representa la tabla de contingencia con recuentos de empleados promovidos según su género.
#
# 2. Prueba de Chi-Cuadrado:
#    - La función `chi2_contingency` de `scipy.stats` realiza la prueba de chi-cuadrado en la tabla de contingencia y devuelve el estadístico de chi-cuadrado, el valor p y otras estadísticas.
#
# 3. Interpretación de los Resultados:
#    - El estadístico de chi-cuadrado se compara con un umbral crítico y el valor p se utiliza para determinar si hay evidencia suficiente para rechazar la hipótesis nula. En este ejemplo, se utiliza un nivel de significancia del 0.05.
#
# Este ejemplo ilustra cómo realizar una prueba de chi-cuadrado para evaluar si hay una asociación significativa entre el género y las promociones en una tabla de contingencia.

# %% [markdown]
# ### Ejemplo: Dsitribución chi-cuadrado
#
# La distribución chi-cuadrado se utiliza comúnmente en estadística inferencial, especialmente en pruebas de hipótesis y en la construcción de intervalos de confianza para la varianza de una población.
#
# En este ejemplo, generaremos datos desde una distribución chi-cuadrado y luego ajustaremos un modelo para estimar los parámetros. También realizaremos un gráfico de la distribución y calcularemos la probabilidad acumulativa.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Generar datos desde una distribución chi-cuadrado
np.random.seed(42)
grados_libertad = 5
datos_chi_cuadrado = np.random.chisquare(df=grados_libertad, size=1000)

# Ajustar una distribución chi-cuadrado a los datos
ajuste_parametros = chi2.fit(datos_chi_cuadrado)

# Crear histograma de los datos
plt.figure(figsize=(6, 6))
plt.hist(datos_chi_cuadrado, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)

# Crear curva de densidad de probabilidad (PDF) de la distribución chi-cuadrado ajustada
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf_ajustada = chi2.pdf(x, *ajuste_parametros)
plt.plot(x, pdf_ajustada, 'k-', linewidth=2)

# Etiquetas y título
plt.title('Distribución Chi-Cuadrado')
plt.xlabel('Valor')
plt.ylabel('Densidad de Probabilidad')
plt.show()

# Calcular probabilidad acumulativa (CDF) para un valor específico
valor_cdf = 10
prob_acumulativa = chi2.cdf(valor_cdf, df=grados_libertad)
print(f"Probabilidad acumulativa para x={valor_cdf}: {prob_acumulativa:.4f}")
# Out:
# Probabilidad acumulativa para x=10: 0.9248

# %% [markdown]
# En este ejemplo, generamos 1000 datos desde una distribución chi-cuadrado con 5 grados de libertad. Luego, ajustamos una distribución chi-cuadrado a los datos y visualizamos la distribución resultante junto con un histograma. Además, calculamos la probabilidad acumulativa para un valor específico (en este caso, x=10).
#
# Puedes ajustar el número de grados de libertad y otros parámetros según tus necesidades. Este ejemplo ilustra cómo trabajar con la distribución chi-cuadrado en Python.

# %% [markdown]
# ### Ideas Clave
# * La distribución chi-cuadrado generalmente se ocupa de recuentos de sujetos o elementos que caen en categorías.
# * La estadística chi-cuadrado mide la magnitud de la desviación de lo que se esperaría en un modelo nulo.

# %% [markdown]
# ### Lecturas Adicionales
# * La distribución chi-cuadrado debe su lugar en la estadística moderna al gran estadístico Karl Pearson y al nacimiento de las pruebas de hipótesis; lee más al respecto en "The Lady Tasting Tea: How Statistics Revolutionized Science in the Twentieth Century" de David Salsburg (W. H. Freeman, 2001).
# * Para una exposición más detallada, consulta la sección en este libro sobre la prueba chi-cuadrado ("Chi-Square Test" en la página 124).

# %% [markdown]
# # Distribución F
#
# Un procedimiento común en la experimentación científica consiste en probar múltiples tratamientos en grupos diferentes, por ejemplo, diferentes fertilizantes en diferentes bloques de un campo. Esto es similar a la prueba A/B/C mencionada en la distribución chi-cuadrado (ver "Distribución Chi-cuadrado" en la página 80), excepto que estamos tratando con valores continuos medidos en lugar de recuentos. En este caso, nos interesa en qué medida las diferencias entre las medias de los grupos son mayores de lo que podríamos esperar bajo la variación aleatoria normal. El estadístico F mide esto y es la razón de la variabilidad entre las medias de los grupos a la variabilidad dentro de cada grupo (también llamada variabilidad residual). Esta comparación se denomina análisis de varianza (ver "ANOVA" en la página 118). La distribución del estadístico F es la distribución de frecuencia de todos los valores que se producirían al permutar aleatoriamente datos en los que todas las medias de los grupos son iguales (es decir, un modelo nulo). Hay varias distribuciones F asociadas con diferentes grados de libertad (por ejemplo, números de grupos, ver "Grados de libertad" en la página 116). El cálculo de F se ilustra en la sección sobre ANOVA. El estadístico F también se utiliza en la regresión lineal para comparar la variación explicada por el modelo de regresión con la variación general en los datos. Los estadísticos F se producen automáticamente en R y Python como parte de los procedimientos de regresión y ANOVA.

# %% [markdown]
# ### Ejemplo de Distribución F: Análisis de Varianza (ANOVA)
#
# Supongamos que estamos realizando un experimento para comparar los rendimientos de tres diferentes tipos de fertilizantes en el crecimiento de plantas. A continuación, se presenta un ejemplo en Python utilizando ANOVA para analizar si hay diferencias significativas entre los rendimientos de los tres grupos:

# %%
import numpy as np
from scipy.stats import f_oneway

# Datos ficticios: rendimientos de plantas con tres tipos de fertilizantes
fertilizante1 = np.array([18, 22, 25, 20, 24])
fertilizante2 = np.array([15, 18, 20, 17, 21])
fertilizante3 = np.array([22, 24, 28, 20, 25])

# Realizar el análisis de varianza (ANOVA)
f_statistic, p_value = f_oneway(fertilizante1, fertilizante2, fertilizante3)

# Mostrar resultados
print(f'Estadístico F: {f_statistic:.4f}')
print(f'Valor p: {p_value:.4f}')

# Interpretar los resultados
alpha = 0.05
if p_value < alpha:
    print("Hay evidencia suficiente para rechazar la hipótesis nula.")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula.")
# Out:
# Estadístico F: 5.2294
# Valor p: 0.0233
# Hay evidencia suficiente para rechazar la hipótesis nula.

# %% [markdown]
# Explicación:
# 1. Definición de los Datos:
#    - `fertilizante1`, `fertilizante2`, `fertilizante3`: Datos ficticios de rendimientos de plantas para tres tipos diferentes de fertilizantes.
#
# 2. Análisis de Varianza (ANOVA):
#    - La función `f_oneway` de `scipy.stats` realiza el análisis de varianza y devuelve el estadístico F y el valor p.
#
# 3. Interpretación de los Resultados:
#    - Se compara el valor p con un umbral de significancia (0.05 en este caso) para determinar si hay evidencia suficiente para rechazar la hipótesis nula de que las medias de los grupos son iguales.
#
# Este ejemplo utiliza ANOVA y la distribución F para evaluar si hay diferencias significativas entre los rendimientos de plantas con tres tipos de fertilizantes diferentes.

# %% [markdown]
# ### Ejemplo: Distribución F
#
# La distribución F se utiliza comúnmente en estadística para comparar varianzas entre dos muestras.
# En este ejemplo, generaremos datos desde una distribución F y luego realizaremos un gráfico de la distribución.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Generar datos desde una distribución F
np.random.seed(42)
grados_libertad_numerador = 5
grados_libertad_denominador = 10
datos_distribucion_f = np.random.f(dfnum=grados_libertad_numerador, dfden=grados_libertad_denominador, size=1000)

# Crear histograma de los datos
plt.figure(figsize=(6, 6))
plt.hist(datos_distribucion_f, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)

# Crear curva de densidad de probabilidad (PDF) de la distribución F
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf_distribucion_f = f.pdf(x, dfn=grados_libertad_numerador, dfd=grados_libertad_denominador)
plt.plot(x, pdf_distribucion_f, 'k-', linewidth=2)

# Etiquetas y título
plt.title('Distribución F')
plt.xlabel('Valor')
plt.ylabel('Densidad de Probabilidad')
plt.show()

# %% [markdown]
# En este código, generamos 1000 datos desde una distribución F con 5 grados de libertad en el numerador y 10 grados de libertad en el denominador. Luego, creamos un histograma para visualizar la distribución de los datos y superponemos una curva de densidad de probabilidad (PDF) de la distribución F.
#
# Puedes ajustar el número de grados de libertad en el numerador y el denominador según tus necesidades. Este ejemplo ilustra cómo trabajar con la distribución F en Python.

# %% [markdown]
# ### Ideas Clave
# * La distribución F se utiliza en experimentos y modelos lineales que involucran datos medidos.
# * El estadístico F compara la variación debida a los factores de interés con la variación general.

# %% [markdown]
# ### Lecturas Adicionales
# La obra "Introduction to Design and Analysis of Experiments" de George Cobb (Wiley, 2008) contiene una excelente exposición de la descomposición de componentes de varianza, lo cual ayuda a comprender ANOVA y el estadístico F.

# %% [markdown]
# # Poisson y Distribuciones Relacionadas
# Muchos procesos producen eventos de manera aleatoria a una tasa general dada, como visitantes que llegan a un sitio web o autos que llegan a una plaza de peaje (eventos distribuidos en el tiempo); imperfecciones en un metro cuadrado de tela o errores tipográficos por cada 100 líneas de código (eventos distribuidos en el espacio).

# %% [markdown]
# ### Ejemplo de Distribución de Poisson: Número de Llegadas a un Sitio Web
#
# Supongamos que estamos estudiando el número promedio de visitantes que llegan a un sitio web en un intervalo de 10 minutos. Podemos modelar este proceso utilizando la Distribución de Poisson. Aquí hay un ejemplo en Python:

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

# Parámetros del proceso de Poisson
tasa_llegadas = 2  # Número promedio de llegadas por intervalo de 10 minutos
intervalo_tiempo = 10  # Duración del intervalo en minutos

# Generar datos simulados de llegadas en un día (144 intervalos de 10 minutos)
datos_simulados = np.random.poisson(tasa_llegadas, 144)

# Crear un histograma de los datos simulados
plt.hist(datos_simulados, bins=range(11), align='left', edgecolor='black', alpha=0.7)
plt.xlabel('Número de Llegadas en 10 Minutos')
plt.ylabel('Frecuencia')
plt.title('Distribución de Poisson: Llegadas a un Sitio Web')
plt.show()

# %% [markdown]
# Explicación:
# 1. Parámetros del Proceso de Poisson:
#    - `tasa_llegadas`: Número promedio de llegadas por intervalo de 10 minutos.
#    - `intervalo_tiempo`: Duración del intervalo en minutos.
#
# 2. Generación de Datos Simulados:
#    - Se utiliza `np.random.poisson` para generar datos simulados de llegadas en un día (144 intervalos de 10 minutos).
#
# 3. Visualización con Histograma:
#    - Se crea un histograma para mostrar la distribución del número de llegadas simuladas.
#
# Este ejemplo simula el número de llegadas a un sitio web en intervalos de 10 minutos a lo largo de un día, utilizando la Distribución de Poisson. La forma de la distribución se asemejará a una distribución de Poisson con una tasa media de llegadas dada.

# %% [markdown]
# ### Términos Clave para Poisson y Distribuciones Relacionadas
#
# ##### Lambda
# * La tasa (por unidad de tiempo o espacio) a la cual ocurren eventos.
#
# ##### Distribución de Poisson
# * La distribución de frecuencia del número de eventos en unidades de tiempo o espacio muestreadas.
#
# ##### Distribución exponencial
# * La distribución de frecuencia del tiempo o distancia entre un evento y el siguiente evento.
#
# ##### Distribución de Weibull
# * Una versión generalizada de la distribución exponencial en la que se permite que la tasa de eventos cambie con el tiempo.

# %% [markdown]
# # Distribuciones de Poisson
# A partir de datos agregados previos (por ejemplo, el número de infecciones de gripe por año), podemos estimar el número promedio de eventos por unidad de tiempo o espacio (por ejemplo, infecciones por día o por unidad censal). También podríamos querer saber cuán diferente podría ser esto de una unidad de tiempo o espacio a otra. La distribución de Poisson nos indica la distribución de eventos por unidad de tiempo o espacio cuando muestreamos muchas de estas unidades. Es útil al abordar preguntas de encolamiento como "¿Cuánta capacidad necesitamos para estar seguros al 95% de procesar completamente el tráfico de Internet que llega a un servidor en cualquier período de cinco segundos?"
#
# El parámetro clave en una distribución de Poisson es λ, o lambda. Este es el número medio de eventos que ocurre en un intervalo especificado de tiempo o espacio. La varianza para una distribución de Poisson también es λ.
#
# Una técnica común es generar números aleatorios a partir de una distribución de Poisson como parte de una simulación de encolamiento. La función rpois en R realiza esto, tomando solo dos argumentos: la cantidad de números aleatorios deseados y lambda:

# %% [markdown]
#     rpois(100, lambda=2)

# %% [markdown]
# La función correspondiente en scipy es `stats.poisson.rvs`:

# %%
# Generar una muestra de 100 números aleatorios utilizando una distribución
#de Poisson con parámetro lambda igual a 2.

stats.poisson.rvs(2, size=100)
# Out:
# array([2, 6, 1, 2, 1, 3, 3, 2, 4, 2, 3, 2, 2, 1, 3, 3, 2, 0, 1, 1, 5, 1,
#        3, 2, 3, 4, 3, 3, 2, 3, 2, 2, 5, 4, 1, 2, 3, 2, 2, 0, 3, 2, 3, 2,
#        3, 2, 2, 2, 3, 2, 1, 1, 3, 0, 0, 3, 2, 2, 0, 2, 1, 2, 3, 1, 5, 1,
#        2, 2, 1, 3, 1, 1, 1, 1, 4, 0, 1, 1, 1, 1, 1, 0, 3, 0, 3, 1, 6, 1,
#        2, 1, 1, 4, 1, 2, 3, 0, 1, 1, 1, 3], dtype=int64)

# %%
# Generar una muestra de 100 números aleatorios a partir de una distribución
#de Poisson con parámetro lambda igual a 2.
sample = stats.poisson.rvs(2, size=100)

# Crear una Serie de pandas a partir de la muestra y visualizar un histograma.
pd.Series(sample).plot.hist()
plt.show()

# %% [markdown]
# Este código generará 100 números aleatorios de una distribución de Poisson con $λ=2$. Por ejemplo, si las llamadas de servicio al cliente entrantes tienen un promedio de dos por minuto, este código simulará 100 minutos, devolviendo el número de llamadas en cada uno de esos 100 minutos.

# %% [markdown]
# # Distribución Exponencial
# Usando el mismo parámetro $λ$ que usamos en la distribución de Poisson, también podemos modelar la distribución del tiempo entre eventos: el tiempo entre visitas a un sitio web o entre la llegada de autos a una caseta de peaje. También se utiliza en ingeniería para modelar el tiempo hasta la falla y en la gestión de procesos para modelar, por ejemplo, el tiempo requerido por llamada de servicio. El código en R para generar números aleatorios de una distribución exponencial toma dos argumentos: $n$ (la cantidad de números a generar) y tasa (el número de eventos por período de tiempo). Por ejemplo:

# %% [markdown]
#     rexp(n=100, rate=0.2)

# %% [markdown]
# En la función `stats.expon.rvs`, el orden de los argumentos está invertido:

# %%
# Generar una muestra de 100 números aleatorios a partir de una distribución
#exponencial con parámetro de escala 0.2.

stats.expon.rvs(0.2, size=100)
# Out:
# array([1.61243749, 0.84275439, 0.45591155, 1.15873377, 0.24116982,
#        0.5947778 , 0.83215932, 0.36011985, 4.37693155, 0.43458041,
#        0.33966805, 0.42757193, 1.66560225, 0.75426503, 1.03336589,
#        0.22123299, 0.23503803, 0.79027575, 1.89638698, 2.36490252,
#        0.29069806, 0.97297663, 2.64449072, 0.69097848, 1.96940616,
#        0.34351899, 2.93945557, 1.5920039 , 3.03590163, 1.32891862,
#        0.65161994, 2.98354731, 0.52236569, 0.60372541, 1.40667117,
#        1.64951663, 2.85077448, 0.42916465, 1.79947785, 1.54149712,
#        0.26592034, 0.68975442, 0.53235237, 0.5631105 , 4.27142207,
#        1.2293962 , 1.46470049, 3.95577327, 0.6735327 , 1.81868134,
#        0.77009974, 2.23664011, 0.39925314, 3.15049464, 0.44688787,
#        0.59485238, 1.61137521, 0.70047132, 1.13703281, 0.78801899,
#        1.55623059, 0.4591999 , 0.26023631, 0.55657409, 0.84304105,
#        0.38394694, 0.63819073, 0.71079732, 0.25910461, 1.07540613,
# ...

# %%
# Generar una muestra de 100 números aleatorios a partir de una distribución
#exponencial con parámetro de escala igual a 5.
sample = stats.expon.rvs(scale=5, size=100)

# Crear una Serie de pandas a partir de la muestra y visualizar un histograma.
pd.Series(sample).plot.hist()
plt.show()

# %% [markdown]
# Este código generaría 100 números aleatorios de una distribución exponencial, donde el número medio de eventos por período de tiempo es 0.2. Por lo tanto, podrías usarlo para simular 100 intervalos, en minutos, entre llamadas de servicio, donde la tasa promedio de llamadas entrantes es de 0.2 por minuto.
#
# Una suposición clave en cualquier estudio de simulación para la distribución de Poisson o exponencial es que la tasa, $λ$, permanece constante durante el período considerado. Esto rara vez es razonable en un sentido global; por ejemplo, el tráfico en carreteras o redes de datos varía según la hora del día y el día de la semana. Sin embargo, los períodos de tiempo o áreas de espacio generalmente se pueden dividir en segmentos que son lo suficientemente homogéneos como para que el análisis o la simulación dentro de esos períodos sea válido.

# %% [markdown]
# # Estimar la Tasa de Fallos
# En muchas aplicaciones, la tasa de eventos, $λ$, es conocida o se puede estimar a partir de datos previos. Sin embargo, para eventos raros, esto no siempre es así. La falla de motores de aeronaves, por ejemplo, es lo suficientemente rara (afortunadamente) que, para un tipo de motor dado, puede haber pocos datos en los que basar una estimación del tiempo entre fallas. Si no hay datos en absoluto, hay poco fundamento para estimar una tasa de eventos. Sin embargo, puedes hacer algunas suposiciones: si no se han observado eventos después de 20 horas, puedes estar bastante seguro de que la tasa no es de 1 por hora. A través de la simulación o el cálculo directo de probabilidades, puedes evaluar diferentes tasas de eventos hipotéticas y estimar valores de umbral por debajo de los cuales la tasa es muy improbable que caiga. Si hay algunos datos pero no son suficientes para proporcionar una estimación precisa y confiable de la tasa, se puede aplicar una prueba de bondad de ajuste (ver "Prueba de Chi-Cuadrado" en la página 124) a varias tasas para determinar qué tan bien se ajustan a los datos observados.

# %% [markdown]
# ### Ejemplo de Estimación de la Tasa de Fallos: Tiempo entre Fallas de Motores de Aeronaves
#
# Supongamos que estamos interesados en estimar la tasa de fallos (tasa de eventos) para un tipo específico de motor de aeronave. No tenemos datos específicos del tiempo entre fallas, pero queremos realizar una estimación inicial.
#
# **Pasos:**
#
# 1. **Suposición de Tasas Hipotéticas:**
#    - Supongamos tasas de eventos hipotéticas en horas, por ejemplo, 0.1 eventos por hora, 0.01 eventos por hora, etc.
#
# 2. **Simulación o Cálculo de Probabilidades:**
#    - Simulamos o calculamos la probabilidad de no experimentar un evento durante un período específico para cada tasa hipotética. Esto podría hacerse mediante simulación de Monte Carlo o utilizando fórmulas de distribución exponencial.
#
# 3. **Estimación de Umbrales:**
#    - Establecemos umbrales de tiempo (por ejemplo, 20 horas) y evaluamos la probabilidad de no experimentar un evento hasta ese momento para cada tasa.
#
# 4. **Prueba de Bondad de Ajuste (Opcional):**
#    - Si hay algunos datos pero no son suficientes, podríamos realizar una prueba de bondad de ajuste para evaluar qué tan bien se ajustan varias tasas a los daal de las probabilidades en función de la tasa.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Suposición de tasas hipotéticas en eventos por hora
tasas_hipoteticas = [0.1, 0.01, 0.001]

# Umbral de tiempo en horas
umbral_tiempo = 20

# Simulación de probabilidad de no experimentar un evento hasta el umbral de tiempo
for tasa in tasas_hipoteticas:
    probabilidad_no_evento = np.exp(-tasa * umbral_tiempo)
    print(f"Tasa: {tasa} eventos por hora, Probabilidad de no evento hasta {umbral_tiempo} horas: {probabilidad_no_evento:.4f}")

# Visualización (opcional): Graficar la probabilidad en función de la tasa
plt.plot(tasas_hipoteticas, [np.exp(-tasa * umbral_tiempo) for tasa in tasas_hipoteticas], marker='o')
plt.xscale('log')  # Escala logarítmica para mejor visualización en tasas pequeñas
plt.xlabel('Tasa de Eventos por Hora')
plt.ylabel('Probabilidad de no Evento hasta 20 horas')
plt.title('Estimación de Tasa de Fallos')
plt.show()
# Out:
# Tasa: 0.1 eventos por hora, Probabilidad de no evento hasta 20 horas: 0.1353
# Tasa: 0.01 eventos por hora, Probabilidad de no evento hasta 20 horas: 0.8187
# Tasa: 0.001 eventos por hora, Probabilidad de no evento hasta 20 horas: 0.9802

# %% [markdown]
# **Explicación:**
# - Se simulan las probabilidades de no experimentar un evento hasta un umbral de tiempo específico para tasas hipotéticas.
# - Se establece un umbral de 20 horas y se evalúan las probabilidades para las tasas hipotéticas.
# - Se realiza una visualización opcional de las probabilidades en función de la tasa.

# %% [markdown]
# # Distribución Weilbull

# %% [markdown]
# En muchos casos, la tasa de eventos no permanece constante con el tiempo. Si el período durante el cual cambia es mucho más largo que el intervalo típico entre eventos, no hay problema; simplemente divides el análisis en los segmentos donde las tasas son relativamente constantes, como se mencionó antes. Sin embargo, si la tasa de eventos cambia a lo largo del tiempo del intervalo, las distribuciones exponencial (o de Poisson) ya no son útiles. Esto es probable que ocurra en fallos mecánicos, donde el riesgo de falla aumenta con el tiempo.
#
# La distribución Weibull es una extensión de la distribución exponencial en la que se permite que la tasa de eventos cambie, según lo especificado por un parámetro de forma, $β$. Si $β> 1$, la probabilidad de un evento aumenta con el tiempo; si $β < 1$, la probabilidad disminuye. Dado que la distribución Weibull se utiliza en el análisis de tiempo hasta la falla en lugar de la tasa de eventos, el segundo parámetro se expresa en términos de la vida característica, en lugar de en términos de la tasa de eventos por intervalo. El símbolo utilizado es $η$, la letra griega eta. También se le llama parámetro de escala.
#
# Con la distribución Weibull, la tarea de estimación ahora incluye la estimación de ambos parámetros, $β$ y $η$. Se utiliza software para modelar los datos y proporcionar una estimación de la distribución Weibull que mejor se ajusta.
#
# El código en R para generar números aleatorios de una distribución Weibull toma tres argumentos: $n$ (la cantidad de números a generar), forma y escala. Por ejemplo, el siguiente código generaría 100 números aleatorios (tiempos de vida) de una distribución Weibull con forma de 1.5 y vida característica de 5,000:

# %% [markdown]
#     rweibull(100, 1.5, 5000)

# %% [markdown]
# Para lograr lo mismo en Python, utiliza la función `stats.weibull_min.rvs`:

# %%
# Generar una muestra de 100 números aleatorios a partir de una distribución de Weibull con parámetros shape=1.5 y scale=5000.

stats.weibull_min.rvs(1.5, scale=5000, size=100)
# Out:
# array([ 2572.80201294,  4292.60893612,  1466.08905465,  3454.54268466,
#         2253.73269753,  2843.80744177,  6914.96313378,  6913.00506384,
#         5705.98864517,  1296.09446604,  2407.48232613,  9937.0050436 ,
#         3566.53221377,  4907.74128942,   349.47671369,  4053.15775264,
#         5546.72269182,   772.14373283,  1233.20473641,  2977.11596547,
#        10146.08028109,  2170.84611057,   390.65868835,  7001.23540999,
#         7648.96567541,  4198.1742597 ,  8548.09493259,  1694.40058727,
#         2344.70158271,   376.48504867,  4576.5930966 ,  8416.15491628,
#         4772.12802688,   956.66624096,  5588.46414139,  5414.29459913,
#         1608.21122463,  7305.17203009,  9049.40117699,  3137.55096803,
#         2573.56973786,  4503.80725729, 11731.97327607,  5927.71353869,
#         6728.14270454,  6445.23789861, 10736.11877543,  7104.8645718 ,
#         2302.04881557,  2052.74657985,  2125.64104449,  1927.99706801,
# ...

# %%
# Generar una muestra de 100 números aleatorios a partir de una distribución de Weibull con parámetros shape=1.5 y scale=5000.
sample = stats.weibull_min.rvs(1.5, scale=5000, size=100)

# Crear una Serie de pandas a partir de la muestra y visualizar un histograma.
pd.Series(sample).plot.hist()
plt.show()

# %% [markdown]
# ### Ideas clave
# * Para eventos que ocurren a una tasa constante, el número de eventos por unidad de tiempo o espacio se puede modelar como una distribución de Poisson.
# * También puedes modelar el tiempo o la distancia entre un evento y el siguiente como una distribución exponencial.
# * Un cambio en la tasa de eventos con el tiempo (por ejemplo, una probabilidad creciente de fallo del dispositivo) se puede modelar con la distribución de Weibull.

# %% [markdown]
# ### Lecturas Adicionales
# * "Modern Engineering Statistics" de Thomas Ryan (Wiley, 2007) tiene un capítulo dedicado a las distribuciones de probabilidad utilizadas en aplicaciones de ingeniería.
# * Lee una perspectiva basada en la ingeniería sobre el uso de la distribución Weibull aquí y aquí.

# %% [markdown]
# # Resumen
# En la era de los grandes datos, los principios de muestreo aleatorio siguen siendo importantes cuando se necesitan estimaciones precisas. La selección aleatoria de datos puede reducir el sesgo y proporcionar un conjunto de datos de mayor calidad que el que se obtendría simplemente utilizando los datos convenientemente disponibles. El conocimiento de diversas distribuciones de muestreo y de generación de datos nos permite cuantificar posibles errores en una estimación que podrían deberse a variaciones aleatorias. Al mismo tiempo, el bootstrap (muestreo con reemplazo de un conjunto de datos observados) es un método atractivo y versátil para determinar posibles errores en las estimaciones de la muestra.
